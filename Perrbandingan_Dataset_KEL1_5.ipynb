# %% [markdown]
# # BENCHMARKING 5 DATASET

# %%
# import library di collab
import time
import pandas as pd
import sys
import os
from google.colab import drive
from IPython import get_ipython
from IPython.display import display

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Dataset paths
github_datasets = {
    'penjualan barang.csv': 'https://raw.githubusercontent.com/Anggunsky/datasetPenjualan/main/penjualan%20barang.csv',
    'data_transaksi.csv': 'https://raw.githubusercontent.com/annisareida/Benchmarking-Algoritma/main/data_transaksi.csv',
}
drive_datasets = {
    'synthetic (1).csv': '/content/drive/MyDrive/DATASET/synthetic (1).csv',
    'Dataset Penjualan Buku.csv': '/content/drive/MyDrive/DATASET/Dataset Penjualan Buku.csv',
    'dataset_tiruan.xlsx': '/content/drive/MyDrive/DATASET/dataset_tiruan.xlsx',
    }
all_datasets = {**github_datasets, **drive_datasets}

# %%
# FUNCTION UTILITIES
def build_hash_index(data, key):
    index = {}
    for item in data:
        value = item.get(key)
        if value is not None:
            if value in index:
                index[value].append(item)
            else:
                index[value] = [item]
    return index

# %%
def hash_search(index, value):
    return index.get(value, [])

# %%
def jump_search(data, key, target):
    n = len(data)
    step = int(n ** 0.5)
    prev = 0
    while prev < n and data[min(n-1, prev)].get(key) < target:
        prev += step
    for i in range(max(0, prev - step), min(prev + 1, n)):
        if data[i].get(key) == target:
            return [data[i]]  # Return as list for consistency with hash_search
    return []

# %%
def bubble_sort(data, key):
    data_copy = data[:]
    n = len(data_copy)
    for i in range(n):
        for j in range(0, n-i-1):
            if data_copy[j].get(key) is not None and data_copy[j+1].get(key) is not None:
                if data_copy[j][key] > data_copy[j+1][key]:
                    data_copy[j], data_copy[j+1] = data_copy[j+1], data_copy[j]
    return data_copy

# %%
def selection_sort(data, key):
    data_copy = data[:]
    n = len(data_copy)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if data_copy[j].get(key) is not None and data_copy[min_idx].get(key) is not None:
                if data_copy[j][key] < data_copy[min_idx][key]:
                    min_idx = j
        data_copy[i], data_copy[min_idx] = data_copy[min_idx], data_copy[i]
    return data_copy

# %%
def hash_bubble(data, key):
    # Build hash index and sort each group using bubble sort
    index = build_hash_index(data, key)
    sorted_data = []
    for value in sorted(index.keys()):
        sorted_group = bubble_sort(index[value], key)
        sorted_data.extend(sorted_group)
    return sorted_data

# %%
def hash_selection(data, key):
    # Build hash index and sort each group using selection sort
    index = build_hash_index(data, key)
    sorted_data = []
    for value in sorted(index.keys()):
        sorted_group = selection_sort(index[value], key)
        sorted_data.extend(sorted_group)
    return sorted_data

# %%
def jump_bubble(data, key, target):
    # Sort using bubble sort, then perform jump search
    sorted_data = bubble_sort(data, key)
    return jump_search(sorted_data, key, target)

# %%
def jump_selection(data, key, target):
    # Sort using selection sort, then perform jump search
    sorted_data = selection_sort(data, key)
    return jump_search(sorted_data, key, target)

# %%
def memory_complexity(data):
    return sys.getsizeof(data)

# %%
# BENCHMARKING FUNCTION
def benchmark(transactions):
    print("\n==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================")

    keys = ['ID', 'Nama Pelanggan', 'Tanggal Pembelian', 'Jumlah Pembelian']
    search_targets = {
        'ID': 30,
        'Nama Pelanggan': 'TOKO HERUNIAWATI',
        'Tanggal Pembelian': '01/02/2020',
        'Jumlah Pembelian': 9840000.0
    }
    # Adjust search targets for data_transaksi.csv
    if any(t['Tanggal Pembelian'].startswith('202') for t in transactions[:5] if isinstance(t['Tanggal Pembelian'], str)):
        search_targets.update({
            'Nama Pelanggan': 'OMODF',
            'Tanggal Pembelian': '28/10/2024',
            'Jumlah Pembelian': 839.53
        })

    for key in keys:
        print(f"\n--- Benchmarking untuk Kolom: {key} ---")

        # Hash Search
        print(f"\n[1] Hash Search (by {key})...")
        start = time.time()
        index = build_hash_index(transactions, key)
        result = hash_search(index, search_targets[key])
        end = time.time()
        print(f"Hasil: {result[:5]}" if len(result) > 5 else f"Hasil: {result}")
        print(f"Waktu Hash Search: {end - start:.6f} detik")
        print(f"Ruang Memori: {memory_complexity(index)} bytes")

        # Jump Search
        print(f"\n[2] Jump Search (by {key})...")
        try:
            sorted_txn = sorted(transactions, key=lambda x: x.get(key, '') if x.get(key) is not None else '')
            start = time.time()
            result = jump_search(sorted_txn, key, search_targets[key])
            end = time.time()
            print(f"Hasil: {result[:5]}" if len(result) > 5 else f"Hasil: {result}")
            print(f"Waktu Jump Search: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_txn)} bytes")
        except TypeError as e:
            print(f"⚠️ Jump Search (by {key}) failed due to data type issues: {e}")

        # Bubble Sort
        print(f"\n[3] Bubble Sort (by {key})...")
        try:
            start = time.time()
            sorted_data = bubble_sort(transactions, key)
            end = time.time()
            print(f"Hasil (5 data pertama): {sorted_data[:5]}")
            print(f"Waktu Bubble Sort: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Bubble Sort (by {key}) failed due to data type issues: {e}")

        # Selection Sort
        print(f"\n[4] Selection Sort (by {key})...")
        try:
            start = time.time()
            sorted_data = selection_sort(transactions, key)
            end = time.time()
            print(f"Hasil (5 data pertama): {sorted_data[:5]}")
            print(f"Waktu Selection Sort: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Selection Sort (by {key}) failed due to data type issues: {e}")

        # Hash-Bubble
        print(f"\n[5] Hash-Bubble (by {key})...")
        try:
            start = time.time()
            sorted_data = hash_bubble(transactions, key)
            end = time.time()
            print(f"Hasil (5 data pertama): {sorted_data[:5]}")
            print(f"Waktu Hash-Bubble: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Hash-Bubble (by {key}) failed due to data type issues: {e}")

        # Hash-Selection
        print(f"\n[6] Hash-Selection (by {key})...")
        try:
            start = time.time()
            sorted_data = hash_selection(transactions, key)
            end = time.time()
            print(f"Hasil (5 data pertama): {sorted_data[:5]}")
            print(f"Waktu Hash-Selection: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Hash-Selection (by {key}) failed due to data type issues: {e}")

        # Jump-Bubble
        print(f"\n[7] Jump-Bubble (by {key})...")
        try:
            start = time.time()
            result = jump_bubble(transactions, key, search_targets[key])
            end = time.time()
            print(f"Hasil: {result[:5]}" if len(result) > 5 else f"Hasil: {result}")
            print(f"Waktu Jump-Bubble: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(transactions)} bytes")
        except TypeError as e:
            print(f"⚠️ Jump-Bubble (by {key}) failed due to data type issues: {e}")

        # Jump-Selection
        print(f"\n[8] Jump-Selection (by {key})...")
        try:
            start = time.time()
            result = jump_selection(transactions, key, search_targets[key])
            end = time.time()
            print(f"Hasil: {result[:5]}" if len(result) > 5 else f"Hasil: {result}")
            print(f"Waktu Jump-Selection: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(transactions)} bytes")
        except TypeError as e:
            print(f"⚠️ Jump-Selection (by {key}) failed due to data type issues: {e}")

# %%
def normalize_columns(df, filename):
    # Column mappings based on actual dataset structures
    if filename == 'penjualan barang.csv':
        mapping = {
            'Unnamed: 0': 'ID',
            'nama.pembeli': 'Nama Pelanggan',
            'tanggal': 'Tanggal Pembelian',
            'nominal': 'Jumlah Pembelian'
        }
        df['nominal'] = pd.to_numeric(df.get('nominal', pd.Series()), errors='coerce')
    elif filename == 'data_transaksi.csv':
        mapping = {
            'id': 'ID',
            'nama': 'Nama Pelanggan',
            'tanggal': 'Tanggal Pembelian',
            'jumlah': 'Jumlah Pembelian'
        }
        # Avoid forcing ID to numeric to preserve data
        df['jumlah'] = pd.to_numeric(df.get('jumlah', pd.Series()), errors='coerce')
    elif filename == 'Dataset Penjualan Buku.csv':
        mapping = {
            'ID': 'ID',
            'Nama_Pelanggan': 'Nama Pelanggan',
            'Tanggal_Pembelian': 'Tanggal Pembelian',
            'Jumlah_Pembelian': 'Jumlah Pembelian'
        }
        df['Jumlah_Pembelian'] = pd.to_numeric(df.get('Jumlah_Pembelian', pd.Series()), errors='coerce')
    elif filename == 'synthetic (1).csv':
        mapping = {
            'ID Pelanggan': 'ID',
            'Nama Pelanggan': 'Nama Pelanggan',
            'Waktu Pembelian': 'Tanggal Pembelian',
            'Jumlah Pembelian': 'Jumlah Pembelian'
        }
        # Avoid forcing ID to numeric to preserve data
        df['Jumlah Pembelian'] = pd.to_numeric(df.get('Jumlah Pembelian', pd.Series()), errors='coerce')
    elif filename == 'dataset_tiruan.xlsx':
        mapping = {
            'ID': 'ID',
            'Nama Pelanggan': 'Nama Pelanggan',
            'Tanggal Pembelian': 'Tanggal Pembelian',
            'Jumlah Pembelian': 'Jumlah Pembelian'
        }
        df['Jumlah Pembelian'] = pd.to_numeric(df.get('Jumlah Pembelian', pd.Series()), errors='coerce')
    else:
        mapping = {}
        print(f"ℹ️ Tidak ada mapping kolom khusus untuk {filename}. Menggunakan kolom asli.")

    if mapping:
        valid_mapping = {k: v for k, v in mapping.items() if k in df.columns}
        if valid_mapping:
            df = df.rename(columns=valid_mapping)
        else:
            print(f"⚠️ Tidak ada kolom yang cocok dengan mapping untuk {filename}. Kolom yang ada: {list(df.columns)}")
    return df

# %%
# MAIN
if __name__ == "__main__":
    for filename, path in all_datasets.items():
        print(f"\n================== MEMUAT DATASET: {filename} ==================")
        try:
            if path.endswith('.xlsx'):
                df = pd.read_excel(path)
            else:
                df = pd.read_csv(path)

            df.columns = [col.strip() for col in df.columns]
            print(f"Kolom asli: {list(df.columns)}")
            df = normalize_columns(df, filename)
            expected_columns = ['ID', 'Nama Pelanggan', 'Tanggal Pembelian', 'Jumlah Pembelian']

            if all(col in df.columns for col in expected_columns):
                df = df[expected_columns].copy()
                # Only convert Jumlah Pembelian to numeric
                df['Jumlah Pembelian'] = pd.to_numeric(df['Jumlah Pembelian'], errors='coerce')
                # Handle date parsing
                if filename == 'data_transaksi.csv':
                    df['Tanggal Pembelian'] = pd.to_datetime(df['Tanggal Pembelian'], format='%Y-%m-%d', errors='coerce').dt.strftime('%d/%m/%Y')
                else:
                    df['Tanggal Pembelian'] = pd.to_datetime(df['Tanggal Pembelian'], errors='coerce').dt.strftime('%d/%m/%Y')

                # Log rows with missing values before dropping
                missing_rows = df[df[expected_columns].isna().any(axis=1)]
                if not missing_rows.empty:
                    print(f"⚠️ {len(missing_rows)} baris dengan nilai kosong di kolom kunci: {missing_rows.head().to_dict(orient='records')}")

                # Drop rows only if critical columns are missing (exclude ID for data_transaksi.csv)
                if filename == 'data_transaksi.csv':
                    df = df.dropna(subset=['Nama Pelanggan', 'Tanggal Pembelian', 'Jumlah Pembelian'])
                else:
                    df = df.dropna(subset=expected_columns)

                transaksi_data = df.to_dict(orient='records')
                print(f"✅ Jumlah Data: {len(transaksi_data)}")
                print("Contoh Data (5 data pertama):")
                for txn in transaksi_data[:5]:
                    print(txn)

                if transaksi_data:
                    benchmark(transaksi_data)
                else:
                    print(f"⚠️ Tidak ada data transaksi yang valid di {filename} setelah pemrosesan. Melewati benchmark.")
            else:
                missing_cols = [col for col in expected_columns if col not in df.columns]
                print(f"❌ Dataset {filename} tidak memiliki kolom yang sesuai setelah normalisasi. Kolom yang hilang: {missing_cols}")
                print(f"Kolom yang ada: {list(df.columns)}")
        except FileNotFoundError:
            print(f"❌ Gagal memproses dataset {filename}: File tidak ditemukan di lokasi: {path}")
        except Exception as e:
            print(f"❌ Gagal memproses dataset {filename}: {e}")
# Out:
# ================== MEMUAT DATASET: penjualan barang.csv ==================
# Kolom asli: ['Unnamed: 0', 'tanggal', 'nama.pembeli', 'nama.barang', 'kuantum', 'nominal']
# ✅ Jumlah Data: 1289
# Contoh Data (5 data pertama):
# {'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0}
# {'ID': 2, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 8400000.0}
# {'ID': 3, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 62910000.0}
# {'ID': 4, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 4855200.0}
# {'ID': 5, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 1162000.0}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID ---
#
# [1] Hash Search (by ID)...
# Hasil: [{'ID': 30, 'Nama Pelanggan': 'TOKO HARYATI ', 'Tanggal Pembelian': '10/01/2020', 'Jumlah Pembelian': 31500000.0}]
# Waktu Hash Search: 0.000508 detik
# Ruang Memori: 36952 bytes
#
# [2] Jump Search (by ID)...
# Hasil: [{'ID': 30, 'Nama Pelanggan': 'TOKO HARYATI ', 'Tanggal Pembelian': '10/01/2020', 'Jumlah Pembelian': 31500000.0}]
# Waktu Jump Search: 0.000012 detik
# Ruang Memori: 10376 bytes
#
# [3] Bubble Sort (by ID)...
# Hasil (5 data pertama): [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0}, {'ID': 2, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 8400000.0}, {'ID': 3, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 62910000.0}, {'ID': 4, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 4855200.0}, {'ID': 5, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 1162000.0}]
# Waktu Bubble Sort: 0.132302 detik
# Ruang Memori: 10368 bytes
#
# [4] Selection Sort (by ID)...
# Hasil (5 data pertama): [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0}, {'ID': 2, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 8400000.0}, {'ID': 3, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 62910000.0}, {'ID': 4, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 4855200.0}, {'ID': 5, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 1162000.0}]
# Waktu Selection Sort: 0.117281 detik
# Ruang Memori: 10368 bytes
#
# [5] Hash-Bubble (by ID)...
# Hasil (5 data pertama): [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0}, {'ID': 2, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 8400000.0}, {'ID': 3, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 62910000.0}, {'ID': 4, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 4855200.0}, {'ID': 5, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 1162000.0}]
# Waktu Hash-Bubble: 0.000831 detik
# Ruang Memori: 11288 bytes
#
# [6] Hash-Selection (by ID)...
# Hasil (5 data pertama): [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0}, {'ID': 2, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 8400000.0}, {'ID': 3, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 62910000.0}, {'ID': 4, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 4855200.0}, {'ID': 5, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 1162000.0}]
# Waktu Hash-Selection: 0.000770 detik
# Ruang Memori: 11288 bytes
#
# [7] Jump-Bubble (by ID)...
# Hasil: [{'ID': 30, 'Nama Pelanggan': 'TOKO HARYATI ', 'Tanggal Pembelian': '10/01/2020', 'Jumlah Pembelian': 31500000.0}]
# Waktu Jump-Bubble: 0.127744 detik
# Ruang Memori: 11288 bytes
#
# [8] Jump-Selection (by ID)...
# Hasil: [{'ID': 30, 'Nama Pelanggan': 'TOKO HARYATI ', 'Tanggal Pembelian': '10/01/2020', 'Jumlah Pembelian': 31500000.0}]
# Waktu Jump-Selection: 0.108758 detik
# Ruang Memori: 11288 bytes
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Hash Search (by Nama Pelanggan)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0}, {'ID': 2, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 8400000.0}, {'ID': 216, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '09/03/2020', 'Jumlah Pembelian': 6868400.0}, {'ID': 217, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '09/03/2020', 'Jumlah Pembelian': 2800000.0}, {'ID': 473, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '19/06/2020', 'Jumlah Pembelian': 13260000.0}]
# Waktu Hash Search: 0.000247 detik
# Ruang Memori: 6576 bytes
#
# [2] Jump Search (by Nama Pelanggan)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0}]
# Waktu Jump Search: 0.000014 detik
# Ruang Memori: 10376 bytes
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 188, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '27/02/2020', 'Jumlah Pembelian': 4911500.0}, {'ID': 189, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '27/02/2020', 'Jumlah Pembelian': 7000000.0}, {'ID': 354, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '28/04/2020', 'Jumlah Pembelian': 15400000.0}, {'ID': 754, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '12/10/2020', 'Jumlah Pembelian': 3692500.0}, {'ID': 755, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '12/10/2020', 'Jumlah Pembelian': 10128000.0}]
# Waktu Bubble Sort: 0.186157 detik
# Ruang Memori: 10368 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 188, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '27/02/2020', 'Jumlah Pembelian': 4911500.0}, {'ID': 189, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '27/02/2020', 'Jumlah Pembelian': 7000000.0}, {'ID': 354, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '28/04/2020', 'Jumlah Pembelian': 15400000.0}, {'ID': 754, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '12/10/2020', 'Jumlah Pembelian': 3692500.0}, {'ID': 755, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '12/10/2020', 'Jumlah Pembelian': 10128000.0}]
# Waktu Selection Sort: 0.140986 detik
# Ruang Memori: 10368 bytes
#
# [5] Hash-Bubble (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 188, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '27/02/2020', 'Jumlah Pembelian': 4911500.0}, {'ID': 189, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '27/02/2020', 'Jumlah Pembelian': 7000000.0}, {'ID': 354, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '28/04/2020', 'Jumlah Pembelian': 15400000.0}, {'ID': 754, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '12/10/2020', 'Jumlah Pembelian': 3692500.0}, {'ID': 755, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '12/10/2020', 'Jumlah Pembelian': 10128000.0}]
# Waktu Hash-Bubble: 0.001894 detik
# Ruang Memori: 11160 bytes
#
# [6] Hash-Selection (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 188, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '27/02/2020', 'Jumlah Pembelian': 4911500.0}, {'ID': 189, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '27/02/2020', 'Jumlah Pembelian': 7000000.0}, {'ID': 354, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '28/04/2020', 'Jumlah Pembelian': 15400000.0}, {'ID': 754, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '12/10/2020', 'Jumlah Pembelian': 3692500.0}, {'ID': 755, 'Nama Pelanggan': 'ANAPSA', 'Tanggal Pembelian': '12/10/2020', 'Jumlah Pembelian': 10128000.0}]
# Waktu Hash-Selection: 0.001780 detik
# Ruang Memori: 11160 bytes
#
# [7] Jump-Bubble (by Nama Pelanggan)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0}]
# Waktu Jump-Bubble: 0.205059 detik
# Ruang Memori: 11288 bytes
#
# [8] Jump-Selection (by Nama Pelanggan)...
# Hasil: [{'ID': 216, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '09/03/2020', 'Jumlah Pembelian': 6868400.0}]
# Waktu Jump-Selection: 0.142092 detik
# Ruang Memori: 11288 bytes
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Hash Search (by Tanggal Pembelian)...
# Hasil: []
# Waktu Hash Search: 0.000250 detik
# Ruang Memori: 6576 bytes
#
# [2] Jump Search (by Tanggal Pembelian)...
# Hasil: []
# Waktu Jump Search: 0.000006 detik
# Ruang Memori: 10376 bytes
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 1023, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 12928608.0}, {'ID': 1024, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 2154000.0}, {'ID': 1025, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 4320000.0}, {'ID': 1172, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 12928608.0}, {'ID': 1173, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 4320000.0}]
# Waktu Bubble Sort: 0.182693 detik
# Ruang Memori: 10368 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 1023, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 12928608.0}, {'ID': 1024, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 2154000.0}, {'ID': 1025, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 4320000.0}, {'ID': 1172, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 12928608.0}, {'ID': 1173, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 4320000.0}]
# Waktu Selection Sort: 0.139531 detik
# Ruang Memori: 10368 bytes
#
# [5] Hash-Bubble (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 1023, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 12928608.0}, {'ID': 1024, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 2154000.0}, {'ID': 1025, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 4320000.0}, {'ID': 1172, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 12928608.0}, {'ID': 1173, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 4320000.0}]
# Waktu Hash-Bubble: 0.001706 detik
# Ruang Memori: 11160 bytes
#
# [6] Hash-Selection (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 1023, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 12928608.0}, {'ID': 1024, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 2154000.0}, {'ID': 1025, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 4320000.0}, {'ID': 1172, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 12928608.0}, {'ID': 1173, 'Nama Pelanggan': 'TOKO NURFADILAH ', 'Tanggal Pembelian': '01/02/2021', 'Jumlah Pembelian': 4320000.0}]
# Waktu Hash-Selection: 0.001599 detik
# Ruang Memori: 11160 bytes
#
# [7] Jump-Bubble (by Tanggal Pembelian)...
# Hasil: []
# Waktu Jump-Bubble: 0.183017 detik
# Ruang Memori: 11288 bytes
#
# [8] Jump-Selection (by Tanggal Pembelian)...
# Hasil: []
# Waktu Jump-Selection: 0.144027 detik
# Ruang Memori: 11288 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Hash Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0}, {'ID': 101, 'Nama Pelanggan': 'TPK PASAR JUNJUNG BUIH', 'Tanggal Pembelian': '03/02/2020', 'Jumlah Pembelian': 9840000.0}]
# Waktu Hash Search: 0.000316 detik
# Ruang Memori: 18512 bytes
#
# [2] Jump Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0}]
# Waktu Jump Search: 0.000012 detik
# Ruang Memori: 10376 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 267, 'Nama Pelanggan': 'YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI', 'Tanggal Pembelian': '24/03/2020', 'Jumlah Pembelian': 46000.0}, {'ID': 632, 'Nama Pelanggan': 'SAHABAT ANDA', 'Tanggal Pembelian': '12/08/2020', 'Jumlah Pembelian': 69000.0}, {'ID': 187, 'Nama Pelanggan': 'YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI', 'Tanggal Pembelian': '27/02/2020', 'Jumlah Pembelian': 92000.0}, {'ID': 343, 'Nama Pelanggan': 'TOKO DARKUM KOPERASI DISPERINDAG ', 'Tanggal Pembelian': '28/04/2020', 'Jumlah Pembelian': 92000.0}, {'ID': 358, 'Nama Pelanggan': 'YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI', 'Tanggal Pembelian': '28/04/2020', 'Jumlah Pembelian': 92000.0}]
# Waktu Bubble Sort: 0.193810 detik
# Ruang Memori: 10368 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 267, 'Nama Pelanggan': 'YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI', 'Tanggal Pembelian': '24/03/2020', 'Jumlah Pembelian': 46000.0}, {'ID': 632, 'Nama Pelanggan': 'SAHABAT ANDA', 'Tanggal Pembelian': '12/08/2020', 'Jumlah Pembelian': 69000.0}, {'ID': 187, 'Nama Pelanggan': 'YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI', 'Tanggal Pembelian': '27/02/2020', 'Jumlah Pembelian': 92000.0}, {'ID': 343, 'Nama Pelanggan': 'TOKO DARKUM KOPERASI DISPERINDAG ', 'Tanggal Pembelian': '28/04/2020', 'Jumlah Pembelian': 92000.0}, {'ID': 358, 'Nama Pelanggan': 'YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI', 'Tanggal Pembelian': '28/04/2020', 'Jumlah Pembelian': 92000.0}]
# Waktu Selection Sort: 0.133620 detik
# Ruang Memori: 10368 bytes
#
# [5] Hash-Bubble (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 267, 'Nama Pelanggan': 'YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI', 'Tanggal Pembelian': '24/03/2020', 'Jumlah Pembelian': 46000.0}, {'ID': 632, 'Nama Pelanggan': 'SAHABAT ANDA', 'Tanggal Pembelian': '12/08/2020', 'Jumlah Pembelian': 69000.0}, {'ID': 187, 'Nama Pelanggan': 'YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI', 'Tanggal Pembelian': '27/02/2020', 'Jumlah Pembelian': 92000.0}, {'ID': 343, 'Nama Pelanggan': 'TOKO DARKUM KOPERASI DISPERINDAG ', 'Tanggal Pembelian': '28/04/2020', 'Jumlah Pembelian': 92000.0}, {'ID': 358, 'Nama Pelanggan': 'YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI', 'Tanggal Pembelian': '28/04/2020', 'Jumlah Pembelian': 92000.0}]
# Waktu Hash-Bubble: 0.001359 detik
# Ruang Memori: 10456 bytes
#
# [6] Hash-Selection (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 267, 'Nama Pelanggan': 'YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI', 'Tanggal Pembelian': '24/03/2020', 'Jumlah Pembelian': 46000.0}, {'ID': 632, 'Nama Pelanggan': 'SAHABAT ANDA', 'Tanggal Pembelian': '12/08/2020', 'Jumlah Pembelian': 69000.0}, {'ID': 187, 'Nama Pelanggan': 'YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI', 'Tanggal Pembelian': '27/02/2020', 'Jumlah Pembelian': 92000.0}, {'ID': 343, 'Nama Pelanggan': 'TOKO DARKUM KOPERASI DISPERINDAG ', 'Tanggal Pembelian': '28/04/2020', 'Jumlah Pembelian': 92000.0}, {'ID': 358, 'Nama Pelanggan': 'YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI', 'Tanggal Pembelian': '28/04/2020', 'Jumlah Pembelian': 92000.0}]
# Waktu Hash-Selection: 0.001199 detik
# Ruang Memori: 10456 bytes
#
# [7] Jump-Bubble (by Jumlah Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0}]
# Waktu Jump-Bubble: 0.175357 detik
# Ruang Memori: 11288 bytes
#
# [8] Jump-Selection (by Jumlah Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0}]
# Waktu Jump-Selection: 0.129770 detik
# Ruang Memori: 11288 bytes
#
# ================== MEMUAT DATASET: data_transaksi.csv ==================
# Kolom asli: ['id', 'nama', 'tanggal', 'jumlah']
# ✅ Jumlah Data: 10000
# Contoh Data (5 data pertama):
# {'ID': 'TRX00000', 'Nama Pelanggan': 'OMODF', 'Tanggal Pembelian': '28/10/2024', 'Jumlah Pembelian': 839.53}
# {'ID': 'TRX00001', 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47}
# {'ID': 'TRX00002', 'Nama Pelanggan': 'MJHYJ', 'Tanggal Pembelian': '29/07/2024', 'Jumlah Pembelian': 103.66}
# {'ID': 'TRX00003', 'Nama Pelanggan': 'XTQTS', 'Tanggal Pembelian': '02/12/2025', 'Jumlah Pembelian': 191.2}
# {'ID': 'TRX00004', 'Nama Pelanggan': 'SFLLP', 'Tanggal Pembelian': '26/03/2025', 'Jumlah Pembelian': 143.33}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID ---
#
# [1] Hash Search (by ID)...
# Hasil: []
# Waktu Hash Search: 0.002165 detik
# Ruang Memori: 207616 bytes
#
# [2] Jump Search (by ID)...
# ⚠️ Jump Search (by ID) failed due to data type issues: '<' not supported between instances of 'str' and 'int'
#
# [3] Bubble Sort (by ID)...
# Hasil (5 data pertama): [{'ID': 'TRX00000', 'Nama Pelanggan': 'OMODF', 'Tanggal Pembelian': '28/10/2024', 'Jumlah Pembelian': 839.53}, {'ID': 'TRX00001', 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47}, {'ID': 'TRX00002', 'Nama Pelanggan': 'MJHYJ', 'Tanggal Pembelian': '29/07/2024', 'Jumlah Pembelian': 103.66}, {'ID': 'TRX00003', 'Nama Pelanggan': 'XTQTS', 'Tanggal Pembelian': '02/12/2025', 'Jumlah Pembelian': 191.2}, {'ID': 'TRX00004', 'Nama Pelanggan': 'SFLLP', 'Tanggal Pembelian': '26/03/2025', 'Jumlah Pembelian': 143.33}]
# Waktu Bubble Sort: 10.687007 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by ID)...
# Hasil (5 data pertama): [{'ID': 'TRX00000', 'Nama Pelanggan': 'OMODF', 'Tanggal Pembelian': '28/10/2024', 'Jumlah Pembelian': 839.53}, {'ID': 'TRX00001', 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47}, {'ID': 'TRX00002', 'Nama Pelanggan': 'MJHYJ', 'Tanggal Pembelian': '29/07/2024', 'Jumlah Pembelian': 103.66}, {'ID': 'TRX00003', 'Nama Pelanggan': 'XTQTS', 'Tanggal Pembelian': '02/12/2025', 'Jumlah Pembelian': 191.2}, {'ID': 'TRX00004', 'Nama Pelanggan': 'SFLLP', 'Tanggal Pembelian': '26/03/2025', 'Jumlah Pembelian': 143.33}]
# Waktu Selection Sort: 9.324269 detik
# Ruang Memori: 80056 bytes
#
# [5] Hash-Bubble (by ID)...
# Hasil (5 data pertama): [{'ID': 'TRX00000', 'Nama Pelanggan': 'OMODF', 'Tanggal Pembelian': '28/10/2024', 'Jumlah Pembelian': 839.53}, {'ID': 'TRX00001', 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47}, {'ID': 'TRX00002', 'Nama Pelanggan': 'MJHYJ', 'Tanggal Pembelian': '29/07/2024', 'Jumlah Pembelian': 103.66}, {'ID': 'TRX00003', 'Nama Pelanggan': 'XTQTS', 'Tanggal Pembelian': '02/12/2025', 'Jumlah Pembelian': 191.2}, {'ID': 'TRX00004', 'Nama Pelanggan': 'SFLLP', 'Tanggal Pembelian': '26/03/2025', 'Jumlah Pembelian': 143.33}]
# Waktu Hash-Bubble: 0.008238 detik
# Ruang Memori: 85176 bytes
#
# [6] Hash-Selection (by ID)...
# Hasil (5 data pertama): [{'ID': 'TRX00000', 'Nama Pelanggan': 'OMODF', 'Tanggal Pembelian': '28/10/2024', 'Jumlah Pembelian': 839.53}, {'ID': 'TRX00001', 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47}, {'ID': 'TRX00002', 'Nama Pelanggan': 'MJHYJ', 'Tanggal Pembelian': '29/07/2024', 'Jumlah Pembelian': 103.66}, {'ID': 'TRX00003', 'Nama Pelanggan': 'XTQTS', 'Tanggal Pembelian': '02/12/2025', 'Jumlah Pembelian': 191.2}, {'ID': 'TRX00004', 'Nama Pelanggan': 'SFLLP', 'Tanggal Pembelian': '26/03/2025', 'Jumlah Pembelian': 143.33}]
# Waktu Hash-Selection: 0.007058 detik
# Ruang Memori: 85176 bytes
#
# [7] Jump-Bubble (by ID)...
# ⚠️ Jump-Bubble (by ID) failed due to data type issues: '<' not supported between instances of 'str' and 'int'
#
# [8] Jump-Selection (by ID)...
# ⚠️ Jump-Selection (by ID) failed due to data type issues: '<' not supported between instances of 'str' and 'int'
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Hash Search (by Nama Pelanggan)...
# Hasil: []
# Waktu Hash Search: 0.062983 detik
# Ruang Memori: 207616 bytes
#
# [2] Jump Search (by Nama Pelanggan)...
# Hasil: []
# Waktu Jump Search: 0.000061 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 'TRX09566', 'Nama Pelanggan': 'AACCL', 'Tanggal Pembelian': '02/09/2023', 'Jumlah Pembelian': 853.57}, {'ID': 'TRX02731', 'Nama Pelanggan': 'AACFT', 'Tanggal Pembelian': '11/11/2025', 'Jumlah Pembelian': 400.83}, {'ID': 'TRX09564', 'Nama Pelanggan': 'AAFDL', 'Tanggal Pembelian': '21/08/2023', 'Jumlah Pembelian': 695.23}, {'ID': 'TRX08671', 'Nama Pelanggan': 'AAFNP', 'Tanggal Pembelian': '20/07/2024', 'Jumlah Pembelian': 342.77}, {'ID': 'TRX03510', 'Nama Pelanggan': 'AAMIK', 'Tanggal Pembelian': '23/11/2025', 'Jumlah Pembelian': 368.35}]
# Waktu Bubble Sort: 14.790779 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 'TRX09566', 'Nama Pelanggan': 'AACCL', 'Tanggal Pembelian': '02/09/2023', 'Jumlah Pembelian': 853.57}, {'ID': 'TRX02731', 'Nama Pelanggan': 'AACFT', 'Tanggal Pembelian': '11/11/2025', 'Jumlah Pembelian': 400.83}, {'ID': 'TRX09564', 'Nama Pelanggan': 'AAFDL', 'Tanggal Pembelian': '21/08/2023', 'Jumlah Pembelian': 695.23}, {'ID': 'TRX08671', 'Nama Pelanggan': 'AAFNP', 'Tanggal Pembelian': '20/07/2024', 'Jumlah Pembelian': 342.77}, {'ID': 'TRX03510', 'Nama Pelanggan': 'AAMIK', 'Tanggal Pembelian': '23/11/2025', 'Jumlah Pembelian': 368.35}]
# Waktu Selection Sort: 11.292595 detik
# Ruang Memori: 80056 bytes
#
# [5] Hash-Bubble (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 'TRX09566', 'Nama Pelanggan': 'AACCL', 'Tanggal Pembelian': '02/09/2023', 'Jumlah Pembelian': 853.57}, {'ID': 'TRX02731', 'Nama Pelanggan': 'AACFT', 'Tanggal Pembelian': '11/11/2025', 'Jumlah Pembelian': 400.83}, {'ID': 'TRX09564', 'Nama Pelanggan': 'AAFDL', 'Tanggal Pembelian': '21/08/2023', 'Jumlah Pembelian': 695.23}, {'ID': 'TRX08671', 'Nama Pelanggan': 'AAFNP', 'Tanggal Pembelian': '20/07/2024', 'Jumlah Pembelian': 342.77}, {'ID': 'TRX03510', 'Nama Pelanggan': 'AAMIK', 'Tanggal Pembelian': '23/11/2025', 'Jumlah Pembelian': 368.35}]
# Waktu Hash-Bubble: 0.010700 detik
# Ruang Memori: 85176 bytes
#
# [6] Hash-Selection (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 'TRX09566', 'Nama Pelanggan': 'AACCL', 'Tanggal Pembelian': '02/09/2023', 'Jumlah Pembelian': 853.57}, {'ID': 'TRX02731', 'Nama Pelanggan': 'AACFT', 'Tanggal Pembelian': '11/11/2025', 'Jumlah Pembelian': 400.83}, {'ID': 'TRX09564', 'Nama Pelanggan': 'AAFDL', 'Tanggal Pembelian': '21/08/2023', 'Jumlah Pembelian': 695.23}, {'ID': 'TRX08671', 'Nama Pelanggan': 'AAFNP', 'Tanggal Pembelian': '20/07/2024', 'Jumlah Pembelian': 342.77}, {'ID': 'TRX03510', 'Nama Pelanggan': 'AAMIK', 'Tanggal Pembelian': '23/11/2025', 'Jumlah Pembelian': 368.35}]
# Waktu Hash-Selection: 0.009480 detik
# Ruang Memori: 85176 bytes
#
# [7] Jump-Bubble (by Nama Pelanggan)...
# Hasil: []
# Waktu Jump-Bubble: 14.782274 detik
# Ruang Memori: 85176 bytes
#
# [8] Jump-Selection (by Nama Pelanggan)...
# Hasil: []
# Waktu Jump-Selection: 11.367995 detik
# Ruang Memori: 85176 bytes
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Hash Search (by Tanggal Pembelian)...
# Hasil: []
# Waktu Hash Search: 0.002495 detik
# Ruang Memori: 26032 bytes
#
# [2] Jump Search (by Tanggal Pembelian)...
# Hasil: []
# Waktu Jump Search: 0.000027 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 'TRX00935', 'Nama Pelanggan': 'MUUOG', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 780.21}, {'ID': 'TRX01239', 'Nama Pelanggan': 'UZXFP', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 43.56}, {'ID': 'TRX01490', 'Nama Pelanggan': 'OHEVA', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 574.23}, {'ID': 'TRX05831', 'Nama Pelanggan': 'RDWHF', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 211.91}, {'ID': 'TRX06007', 'Nama Pelanggan': 'BNQZV', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 93.03}]
# Waktu Bubble Sort: 15.256145 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 'TRX00935', 'Nama Pelanggan': 'MUUOG', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 780.21}, {'ID': 'TRX01239', 'Nama Pelanggan': 'UZXFP', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 43.56}, {'ID': 'TRX01490', 'Nama Pelanggan': 'OHEVA', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 574.23}, {'ID': 'TRX05831', 'Nama Pelanggan': 'RDWHF', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 211.91}, {'ID': 'TRX06007', 'Nama Pelanggan': 'BNQZV', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 93.03}]
# Waktu Selection Sort: 11.566950 detik
# Ruang Memori: 80056 bytes
#
# [5] Hash-Bubble (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 'TRX00935', 'Nama Pelanggan': 'MUUOG', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 780.21}, {'ID': 'TRX01239', 'Nama Pelanggan': 'UZXFP', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 43.56}, {'ID': 'TRX01490', 'Nama Pelanggan': 'OHEVA', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 574.23}, {'ID': 'TRX05831', 'Nama Pelanggan': 'RDWHF', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 211.91}, {'ID': 'TRX06007', 'Nama Pelanggan': 'BNQZV', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 93.03}]
# Waktu Hash-Bubble: 0.013652 detik
# Ruang Memori: 89976 bytes
#
# [6] Hash-Selection (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 'TRX00935', 'Nama Pelanggan': 'MUUOG', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 780.21}, {'ID': 'TRX01239', 'Nama Pelanggan': 'UZXFP', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 43.56}, {'ID': 'TRX01490', 'Nama Pelanggan': 'OHEVA', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 574.23}, {'ID': 'TRX05831', 'Nama Pelanggan': 'RDWHF', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 211.91}, {'ID': 'TRX06007', 'Nama Pelanggan': 'BNQZV', 'Tanggal Pembelian': '01/01/2023', 'Jumlah Pembelian': 93.03}]
# Waktu Hash-Selection: 0.012358 detik
# Ruang Memori: 89976 bytes
#
# [7] Jump-Bubble (by Tanggal Pembelian)...
# Hasil: []
# Waktu Jump-Bubble: 15.850129 detik
# Ruang Memori: 85176 bytes
#
# [8] Jump-Selection (by Tanggal Pembelian)...
# Hasil: []
# Waktu Jump-Selection: 14.940941 detik
# Ruang Memori: 85176 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Hash Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Hash Search: 0.006389 detik
# Ruang Memori: 294992 bytes
#
# [2] Jump Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Jump Search: 0.000082 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 'TRX03791', 'Nama Pelanggan': 'YFEPN', 'Tanggal Pembelian': '28/06/2025', 'Jumlah Pembelian': 10.04}, {'ID': 'TRX08871', 'Nama Pelanggan': 'NYAPN', 'Tanggal Pembelian': '23/01/2023', 'Jumlah Pembelian': 10.08}, {'ID': 'TRX03323', 'Nama Pelanggan': 'LPKYU', 'Tanggal Pembelian': '11/10/2024', 'Jumlah Pembelian': 10.14}, {'ID': 'TRX08661', 'Nama Pelanggan': 'MWWYL', 'Tanggal Pembelian': '24/03/2025', 'Jumlah Pembelian': 10.22}, {'ID': 'TRX04888', 'Nama Pelanggan': 'BNFLK', 'Tanggal Pembelian': '24/04/2024', 'Jumlah Pembelian': 10.31}]
# Waktu Bubble Sort: 14.225600 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 'TRX03791', 'Nama Pelanggan': 'YFEPN', 'Tanggal Pembelian': '28/06/2025', 'Jumlah Pembelian': 10.04}, {'ID': 'TRX08871', 'Nama Pelanggan': 'NYAPN', 'Tanggal Pembelian': '23/01/2023', 'Jumlah Pembelian': 10.08}, {'ID': 'TRX03323', 'Nama Pelanggan': 'LPKYU', 'Tanggal Pembelian': '11/10/2024', 'Jumlah Pembelian': 10.14}, {'ID': 'TRX08661', 'Nama Pelanggan': 'MWWYL', 'Tanggal Pembelian': '24/03/2025', 'Jumlah Pembelian': 10.22}, {'ID': 'TRX04888', 'Nama Pelanggan': 'BNFLK', 'Tanggal Pembelian': '24/04/2024', 'Jumlah Pembelian': 10.31}]
# Waktu Selection Sort: 9.185603 detik
# Ruang Memori: 80056 bytes
#
# [5] Hash-Bubble (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 'TRX03791', 'Nama Pelanggan': 'YFEPN', 'Tanggal Pembelian': '28/06/2025', 'Jumlah Pembelian': 10.04}, {'ID': 'TRX08871', 'Nama Pelanggan': 'NYAPN', 'Tanggal Pembelian': '23/01/2023', 'Jumlah Pembelian': 10.08}, {'ID': 'TRX03323', 'Nama Pelanggan': 'LPKYU', 'Tanggal Pembelian': '11/10/2024', 'Jumlah Pembelian': 10.14}, {'ID': 'TRX08661', 'Nama Pelanggan': 'MWWYL', 'Tanggal Pembelian': '24/03/2025', 'Jumlah Pembelian': 10.22}, {'ID': 'TRX04888', 'Nama Pelanggan': 'BNFLK', 'Tanggal Pembelian': '24/04/2024', 'Jumlah Pembelian': 10.31}]
# Waktu Hash-Bubble: 0.018996 detik
# Ruang Memori: 85912 bytes
#
# [6] Hash-Selection (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 'TRX03791', 'Nama Pelanggan': 'YFEPN', 'Tanggal Pembelian': '28/06/2025', 'Jumlah Pembelian': 10.04}, {'ID': 'TRX08871', 'Nama Pelanggan': 'NYAPN', 'Tanggal Pembelian': '23/01/2023', 'Jumlah Pembelian': 10.08}, {'ID': 'TRX03323', 'Nama Pelanggan': 'LPKYU', 'Tanggal Pembelian': '11/10/2024', 'Jumlah Pembelian': 10.14}, {'ID': 'TRX08661', 'Nama Pelanggan': 'MWWYL', 'Tanggal Pembelian': '24/03/2025', 'Jumlah Pembelian': 10.22}, {'ID': 'TRX04888', 'Nama Pelanggan': 'BNFLK', 'Tanggal Pembelian': '24/04/2024', 'Jumlah Pembelian': 10.31}]
# Waktu Hash-Selection: 0.013994 detik
# Ruang Memori: 85912 bytes
#
# [7] Jump-Bubble (by Jumlah Pembelian)...
# Hasil: []
# Waktu Jump-Bubble: 15.299778 detik
# Ruang Memori: 85176 bytes
#
# [8] Jump-Selection (by Jumlah Pembelian)...
# Hasil: []
# Waktu Jump-Selection: 10.036789 detik
# Ruang Memori: 85176 bytes
#
# ================== MEMUAT DATASET: synthetic (1).csv ==================
# Kolom asli: ['ID Pelanggan', 'Nama Pelanggan', 'Waktu Pembelian', 'Jumlah Pembelian']
# ✅ Jumlah Data: 10000
# Contoh Data (5 data pertama):
# {'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031}
# {'ID': 2, 'Nama Pelanggan': 'Kirana Susanti', 'Tanggal Pembelian': '28/09/2024', 'Jumlah Pembelian': 21199}
# {'ID': 3, 'Nama Pelanggan': 'Gita Bayhaqie', 'Tanggal Pembelian': '19/07/2024', 'Jumlah Pembelian': 39819}
# {'ID': 4, 'Nama Pelanggan': 'Aditya Wulandari', 'Tanggal Pembelian': '14/03/2024', 'Jumlah Pembelian': 485896}
# {'ID': 5, 'Nama Pelanggan': 'Omar Sulistyo', 'Tanggal Pembelian': '22/07/2024', 'Jumlah Pembelian': 72706}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID ---
#
# [1] Hash Search (by ID)...
# Hasil: [{'ID': 30, 'Nama Pelanggan': 'Alex Aryani', 'Tanggal Pembelian': '23/03/2024', 'Jumlah Pembelian': 483953}]
# Waktu Hash Search: 0.002098 detik
# Ruang Memori: 294992 bytes
#
# [2] Jump Search (by ID)...
# Hasil: [{'ID': 30, 'Nama Pelanggan': 'Alex Aryani', 'Tanggal Pembelian': '23/03/2024', 'Jumlah Pembelian': 483953}]
# Waktu Jump Search: 0.000011 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by ID)...
# Hasil (5 data pertama): [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031}, {'ID': 2, 'Nama Pelanggan': 'Kirana Susanti', 'Tanggal Pembelian': '28/09/2024', 'Jumlah Pembelian': 21199}, {'ID': 3, 'Nama Pelanggan': 'Gita Bayhaqie', 'Tanggal Pembelian': '19/07/2024', 'Jumlah Pembelian': 39819}, {'ID': 4, 'Nama Pelanggan': 'Aditya Wulandari', 'Tanggal Pembelian': '14/03/2024', 'Jumlah Pembelian': 485896}, {'ID': 5, 'Nama Pelanggan': 'Omar Sulistyo', 'Tanggal Pembelian': '22/07/2024', 'Jumlah Pembelian': 72706}]
# Waktu Bubble Sort: 9.967529 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by ID)...
# Hasil (5 data pertama): [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031}, {'ID': 2, 'Nama Pelanggan': 'Kirana Susanti', 'Tanggal Pembelian': '28/09/2024', 'Jumlah Pembelian': 21199}, {'ID': 3, 'Nama Pelanggan': 'Gita Bayhaqie', 'Tanggal Pembelian': '19/07/2024', 'Jumlah Pembelian': 39819}, {'ID': 4, 'Nama Pelanggan': 'Aditya Wulandari', 'Tanggal Pembelian': '14/03/2024', 'Jumlah Pembelian': 485896}, {'ID': 5, 'Nama Pelanggan': 'Omar Sulistyo', 'Tanggal Pembelian': '22/07/2024', 'Jumlah Pembelian': 72706}]
# Waktu Selection Sort: 8.179516 detik
# Ruang Memori: 80056 bytes
#
# [5] Hash-Bubble (by ID)...
# Hasil (5 data pertama): [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031}, {'ID': 2, 'Nama Pelanggan': 'Kirana Susanti', 'Tanggal Pembelian': '28/09/2024', 'Jumlah Pembelian': 21199}, {'ID': 3, 'Nama Pelanggan': 'Gita Bayhaqie', 'Tanggal Pembelian': '19/07/2024', 'Jumlah Pembelian': 39819}, {'ID': 4, 'Nama Pelanggan': 'Aditya Wulandari', 'Tanggal Pembelian': '14/03/2024', 'Jumlah Pembelian': 485896}, {'ID': 5, 'Nama Pelanggan': 'Omar Sulistyo', 'Tanggal Pembelian': '22/07/2024', 'Jumlah Pembelian': 72706}]
# Waktu Hash-Bubble: 0.007187 detik
# Ruang Memori: 85176 bytes
#
# [6] Hash-Selection (by ID)...
# Hasil (5 data pertama): [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031}, {'ID': 2, 'Nama Pelanggan': 'Kirana Susanti', 'Tanggal Pembelian': '28/09/2024', 'Jumlah Pembelian': 21199}, {'ID': 3, 'Nama Pelanggan': 'Gita Bayhaqie', 'Tanggal Pembelian': '19/07/2024', 'Jumlah Pembelian': 39819}, {'ID': 4, 'Nama Pelanggan': 'Aditya Wulandari', 'Tanggal Pembelian': '14/03/2024', 'Jumlah Pembelian': 485896}, {'ID': 5, 'Nama Pelanggan': 'Omar Sulistyo', 'Tanggal Pembelian': '22/07/2024', 'Jumlah Pembelian': 72706}]
# Waktu Hash-Selection: 0.006484 detik
# Ruang Memori: 85176 bytes
#
# [7] Jump-Bubble (by ID)...
# Hasil: [{'ID': 30, 'Nama Pelanggan': 'Alex Aryani', 'Tanggal Pembelian': '23/03/2024', 'Jumlah Pembelian': 483953}]
# Waktu Jump-Bubble: 8.349229 detik
# Ruang Memori: 85176 bytes
#
# [8] Jump-Selection (by ID)...
# Hasil: [{'ID': 30, 'Nama Pelanggan': 'Alex Aryani', 'Tanggal Pembelian': '23/03/2024', 'Jumlah Pembelian': 483953}]
# Waktu Jump-Selection: 8.170410 detik
# Ruang Memori: 85176 bytes
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Hash Search (by Nama Pelanggan)...
# Hasil: []
# Waktu Hash Search: 0.060357 detik
# Ruang Memori: 207616 bytes
#
# [2] Jump Search (by Nama Pelanggan)...
# Hasil: []
# Waktu Jump Search: 0.000049 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 6912, 'Nama Pelanggan': 'Abdi Adinata', 'Tanggal Pembelian': '26/05/2024', 'Jumlah Pembelian': 328347}, {'ID': 2267, 'Nama Pelanggan': 'Abdi Aji', 'Tanggal Pembelian': '27/10/2024', 'Jumlah Pembelian': 307265}, {'ID': 1389, 'Nama Pelanggan': 'Abdi Almira', 'Tanggal Pembelian': '18/04/2024', 'Jumlah Pembelian': 287647}, {'ID': 2107, 'Nama Pelanggan': 'Abdi Almira', 'Tanggal Pembelian': '17/10/2024', 'Jumlah Pembelian': 376430}, {'ID': 7924, 'Nama Pelanggan': 'Abdi Almira', 'Tanggal Pembelian': '06/02/2024', 'Jumlah Pembelian': 84684}]
# Waktu Bubble Sort: 14.623022 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 6912, 'Nama Pelanggan': 'Abdi Adinata', 'Tanggal Pembelian': '26/05/2024', 'Jumlah Pembelian': 328347}, {'ID': 2267, 'Nama Pelanggan': 'Abdi Aji', 'Tanggal Pembelian': '27/10/2024', 'Jumlah Pembelian': 307265}, {'ID': 1389, 'Nama Pelanggan': 'Abdi Almira', 'Tanggal Pembelian': '18/04/2024', 'Jumlah Pembelian': 287647}, {'ID': 2107, 'Nama Pelanggan': 'Abdi Almira', 'Tanggal Pembelian': '17/10/2024', 'Jumlah Pembelian': 376430}, {'ID': 7924, 'Nama Pelanggan': 'Abdi Almira', 'Tanggal Pembelian': '06/02/2024', 'Jumlah Pembelian': 84684}]
# Waktu Selection Sort: 11.089007 detik
# Ruang Memori: 80056 bytes
#
# [5] Hash-Bubble (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 6912, 'Nama Pelanggan': 'Abdi Adinata', 'Tanggal Pembelian': '26/05/2024', 'Jumlah Pembelian': 328347}, {'ID': 2267, 'Nama Pelanggan': 'Abdi Aji', 'Tanggal Pembelian': '27/10/2024', 'Jumlah Pembelian': 307265}, {'ID': 1389, 'Nama Pelanggan': 'Abdi Almira', 'Tanggal Pembelian': '18/04/2024', 'Jumlah Pembelian': 287647}, {'ID': 2107, 'Nama Pelanggan': 'Abdi Almira', 'Tanggal Pembelian': '17/10/2024', 'Jumlah Pembelian': 376430}, {'ID': 7924, 'Nama Pelanggan': 'Abdi Almira', 'Tanggal Pembelian': '06/02/2024', 'Jumlah Pembelian': 84684}]
# Waktu Hash-Bubble: 0.009520 detik
# Ruang Memori: 80984 bytes
#
# [6] Hash-Selection (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 6912, 'Nama Pelanggan': 'Abdi Adinata', 'Tanggal Pembelian': '26/05/2024', 'Jumlah Pembelian': 328347}, {'ID': 2267, 'Nama Pelanggan': 'Abdi Aji', 'Tanggal Pembelian': '27/10/2024', 'Jumlah Pembelian': 307265}, {'ID': 1389, 'Nama Pelanggan': 'Abdi Almira', 'Tanggal Pembelian': '18/04/2024', 'Jumlah Pembelian': 287647}, {'ID': 2107, 'Nama Pelanggan': 'Abdi Almira', 'Tanggal Pembelian': '17/10/2024', 'Jumlah Pembelian': 376430}, {'ID': 7924, 'Nama Pelanggan': 'Abdi Almira', 'Tanggal Pembelian': '06/02/2024', 'Jumlah Pembelian': 84684}]
# Waktu Hash-Selection: 0.009359 detik
# Ruang Memori: 80984 bytes
#
# [7] Jump-Bubble (by Nama Pelanggan)...
# Hasil: []
# Waktu Jump-Bubble: 14.691517 detik
# Ruang Memori: 85176 bytes
#
# [8] Jump-Selection (by Nama Pelanggan)...
# Hasil: []
# Waktu Jump-Selection: 11.110708 detik
# Ruang Memori: 85176 bytes
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Hash Search (by Tanggal Pembelian)...
# Hasil: []
# Waktu Hash Search: 0.002149 detik
# Ruang Memori: 13056 bytes
#
# [2] Jump Search (by Tanggal Pembelian)...
# Hasil: []
# Waktu Jump Search: 0.000028 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 114, 'Nama Pelanggan': 'Veron Kusnadi', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 80510}, {'ID': 613, 'Nama Pelanggan': 'Elok Wibowo', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 229744}, {'ID': 654, 'Nama Pelanggan': 'Hani Mahardika', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 224317}, {'ID': 1005, 'Nama Pelanggan': 'Qomar Sapari', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 136617}, {'ID': 1061, 'Nama Pelanggan': 'Ulya Kusnadi', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 476547}]
# Waktu Bubble Sort: 15.163388 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 114, 'Nama Pelanggan': 'Veron Kusnadi', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 80510}, {'ID': 613, 'Nama Pelanggan': 'Elok Wibowo', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 229744}, {'ID': 654, 'Nama Pelanggan': 'Hani Mahardika', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 224317}, {'ID': 1005, 'Nama Pelanggan': 'Qomar Sapari', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 136617}, {'ID': 1061, 'Nama Pelanggan': 'Ulya Kusnadi', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 476547}]
# Waktu Selection Sort: 11.434597 detik
# Ruang Memori: 80056 bytes
#
# [5] Hash-Bubble (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 114, 'Nama Pelanggan': 'Veron Kusnadi', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 80510}, {'ID': 613, 'Nama Pelanggan': 'Elok Wibowo', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 229744}, {'ID': 654, 'Nama Pelanggan': 'Hani Mahardika', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 224317}, {'ID': 1005, 'Nama Pelanggan': 'Qomar Sapari', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 136617}, {'ID': 1061, 'Nama Pelanggan': 'Ulya Kusnadi', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 476547}]
# Waktu Hash-Bubble: 0.028982 detik
# Ruang Memori: 86168 bytes
#
# [6] Hash-Selection (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 114, 'Nama Pelanggan': 'Veron Kusnadi', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 80510}, {'ID': 613, 'Nama Pelanggan': 'Elok Wibowo', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 229744}, {'ID': 654, 'Nama Pelanggan': 'Hani Mahardika', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 224317}, {'ID': 1005, 'Nama Pelanggan': 'Qomar Sapari', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 136617}, {'ID': 1061, 'Nama Pelanggan': 'Ulya Kusnadi', 'Tanggal Pembelian': '01/01/2024', 'Jumlah Pembelian': 476547}]
# Waktu Hash-Selection: 0.030913 detik
# Ruang Memori: 86168 bytes
#
# [7] Jump-Bubble (by Tanggal Pembelian)...
# Hasil: []
# Waktu Jump-Bubble: 15.228230 detik
# Ruang Memori: 85176 bytes
#
# [8] Jump-Selection (by Tanggal Pembelian)...
# Hasil: []
# Waktu Jump-Selection: 11.502747 detik
# Ruang Memori: 85176 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Hash Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Hash Search: 0.003535 detik
# Ruang Memori: 294992 bytes
#
# [2] Jump Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Jump Search: 0.000062 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 6660, 'Nama Pelanggan': 'Dewi Saputra', 'Tanggal Pembelian': '27/04/2024', 'Jumlah Pembelian': 10001}, {'ID': 882, 'Nama Pelanggan': 'Tono Syahrul', 'Tanggal Pembelian': '26/09/2024', 'Jumlah Pembelian': 10022}, {'ID': 9226, 'Nama Pelanggan': 'Rizky Adinata', 'Tanggal Pembelian': '10/09/2024', 'Jumlah Pembelian': 10131}, {'ID': 4282, 'Nama Pelanggan': 'Nabil Yunita', 'Tanggal Pembelian': '08/01/2024', 'Jumlah Pembelian': 10164}, {'ID': 8567, 'Nama Pelanggan': 'Iqbal Yap', 'Tanggal Pembelian': '13/09/2024', 'Jumlah Pembelian': 10247}]
# Waktu Bubble Sort: 14.368974 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 6660, 'Nama Pelanggan': 'Dewi Saputra', 'Tanggal Pembelian': '27/04/2024', 'Jumlah Pembelian': 10001}, {'ID': 882, 'Nama Pelanggan': 'Tono Syahrul', 'Tanggal Pembelian': '26/09/2024', 'Jumlah Pembelian': 10022}, {'ID': 9226, 'Nama Pelanggan': 'Rizky Adinata', 'Tanggal Pembelian': '10/09/2024', 'Jumlah Pembelian': 10131}, {'ID': 4282, 'Nama Pelanggan': 'Nabil Yunita', 'Tanggal Pembelian': '08/01/2024', 'Jumlah Pembelian': 10164}, {'ID': 8567, 'Nama Pelanggan': 'Iqbal Yap', 'Tanggal Pembelian': '13/09/2024', 'Jumlah Pembelian': 10247}]
# Waktu Selection Sort: 10.583889 detik
# Ruang Memori: 80056 bytes
#
# [5] Hash-Bubble (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 6660, 'Nama Pelanggan': 'Dewi Saputra', 'Tanggal Pembelian': '27/04/2024', 'Jumlah Pembelian': 10001}, {'ID': 882, 'Nama Pelanggan': 'Tono Syahrul', 'Tanggal Pembelian': '26/09/2024', 'Jumlah Pembelian': 10022}, {'ID': 9226, 'Nama Pelanggan': 'Rizky Adinata', 'Tanggal Pembelian': '10/09/2024', 'Jumlah Pembelian': 10131}, {'ID': 4282, 'Nama Pelanggan': 'Nabil Yunita', 'Tanggal Pembelian': '08/01/2024', 'Jumlah Pembelian': 10164}, {'ID': 8567, 'Nama Pelanggan': 'Iqbal Yap', 'Tanggal Pembelian': '13/09/2024', 'Jumlah Pembelian': 10247}]
# Waktu Hash-Bubble: 0.010293 detik
# Ruang Memori: 85176 bytes
#
# [6] Hash-Selection (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 6660, 'Nama Pelanggan': 'Dewi Saputra', 'Tanggal Pembelian': '27/04/2024', 'Jumlah Pembelian': 10001}, {'ID': 882, 'Nama Pelanggan': 'Tono Syahrul', 'Tanggal Pembelian': '26/09/2024', 'Jumlah Pembelian': 10022}, {'ID': 9226, 'Nama Pelanggan': 'Rizky Adinata', 'Tanggal Pembelian': '10/09/2024', 'Jumlah Pembelian': 10131}, {'ID': 4282, 'Nama Pelanggan': 'Nabil Yunita', 'Tanggal Pembelian': '08/01/2024', 'Jumlah Pembelian': 10164}, {'ID': 8567, 'Nama Pelanggan': 'Iqbal Yap', 'Tanggal Pembelian': '13/09/2024', 'Jumlah Pembelian': 10247}]
# Waktu Hash-Selection: 0.008996 detik
# Ruang Memori: 85176 bytes
#
# [7] Jump-Bubble (by Jumlah Pembelian)...
# Hasil: []
# Waktu Jump-Bubble: 14.324260 detik
# Ruang Memori: 85176 bytes
#
# [8] Jump-Selection (by Jumlah Pembelian)...
# Hasil: []
# Waktu Jump-Selection: 10.567240 detik
# Ruang Memori: 85176 bytes
#
# ================== MEMUAT DATASET: Dataset Penjualan Buku.csv ==================
# Kolom asli: ['ID', 'Nama_Pelanggan', 'Tanggal_Pembelian', 'Jumlah_Pembelian', 'Kategori_Buku', 'Harga_Satuan', 'Total_Harga']
# ✅ Jumlah Data: 10000
# Contoh Data (5 data pertama):
# {'ID': 'TRX001944', 'Nama Pelanggan': 'Balidin Dongoran, S.T.', 'Tanggal Pembelian': '30/08/2024', 'Jumlah Pembelian': 7}
# {'ID': 'TRX002455', 'Nama Pelanggan': 'Darmana Mandala', 'Tanggal Pembelian': '05/12/2024', 'Jumlah Pembelian': 20}
# {'ID': 'TRX003512', 'Nama Pelanggan': 'Ciaobella Wastuti, M.Pd', 'Tanggal Pembelian': '14/08/2024', 'Jumlah Pembelian': 15}
# {'ID': 'TRX003354', 'Nama Pelanggan': 'Lantar Anggraini', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 11}
# {'ID': 'TRX002721', 'Nama Pelanggan': 'Among Iswahyudi', 'Tanggal Pembelian': '04/07/2024', 'Jumlah Pembelian': 8}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID ---
#
# [1] Hash Search (by ID)...
# Hasil: []
# Waktu Hash Search: 0.002127 detik
# Ruang Memori: 207616 bytes
#
# [2] Jump Search (by ID)...
# ⚠️ Jump Search (by ID) failed due to data type issues: '<' not supported between instances of 'str' and 'int'
#
# [3] Bubble Sort (by ID)...
# Hasil (5 data pertama): [{'ID': 'TRX000001', 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6}, {'ID': 'TRX000002', 'Nama Pelanggan': 'Elvina Dongoran', 'Tanggal Pembelian': '27/10/2024', 'Jumlah Pembelian': 18}, {'ID': 'TRX000003', 'Nama Pelanggan': 'Cut Vicky Utami', 'Tanggal Pembelian': '03/11/2024', 'Jumlah Pembelian': 19}, {'ID': 'TRX000004', 'Nama Pelanggan': 'drg. Mumpuni Lazuardi, S.T.', 'Tanggal Pembelian': '02/02/2025', 'Jumlah Pembelian': 10}, {'ID': 'TRX000005', 'Nama Pelanggan': 'Ganep Zulaika', 'Tanggal Pembelian': '29/08/2024', 'Jumlah Pembelian': 3}]
# Waktu Bubble Sort: 15.139751 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by ID)...
# Hasil (5 data pertama): [{'ID': 'TRX000001', 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6}, {'ID': 'TRX000002', 'Nama Pelanggan': 'Elvina Dongoran', 'Tanggal Pembelian': '27/10/2024', 'Jumlah Pembelian': 18}, {'ID': 'TRX000003', 'Nama Pelanggan': 'Cut Vicky Utami', 'Tanggal Pembelian': '03/11/2024', 'Jumlah Pembelian': 19}, {'ID': 'TRX000004', 'Nama Pelanggan': 'drg. Mumpuni Lazuardi, S.T.', 'Tanggal Pembelian': '02/02/2025', 'Jumlah Pembelian': 10}, {'ID': 'TRX000005', 'Nama Pelanggan': 'Ganep Zulaika', 'Tanggal Pembelian': '29/08/2024', 'Jumlah Pembelian': 3}]
# Waktu Selection Sort: 10.108668 detik
# Ruang Memori: 80056 bytes
#
# [5] Hash-Bubble (by ID)...
# Hasil (5 data pertama): [{'ID': 'TRX000001', 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6}, {'ID': 'TRX000002', 'Nama Pelanggan': 'Elvina Dongoran', 'Tanggal Pembelian': '27/10/2024', 'Jumlah Pembelian': 18}, {'ID': 'TRX000003', 'Nama Pelanggan': 'Cut Vicky Utami', 'Tanggal Pembelian': '03/11/2024', 'Jumlah Pembelian': 19}, {'ID': 'TRX000004', 'Nama Pelanggan': 'drg. Mumpuni Lazuardi, S.T.', 'Tanggal Pembelian': '02/02/2025', 'Jumlah Pembelian': 10}, {'ID': 'TRX000005', 'Nama Pelanggan': 'Ganep Zulaika', 'Tanggal Pembelian': '29/08/2024', 'Jumlah Pembelian': 3}]
# Waktu Hash-Bubble: 0.010945 detik
# Ruang Memori: 85176 bytes
#
# [6] Hash-Selection (by ID)...
# Hasil (5 data pertama): [{'ID': 'TRX000001', 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6}, {'ID': 'TRX000002', 'Nama Pelanggan': 'Elvina Dongoran', 'Tanggal Pembelian': '27/10/2024', 'Jumlah Pembelian': 18}, {'ID': 'TRX000003', 'Nama Pelanggan': 'Cut Vicky Utami', 'Tanggal Pembelian': '03/11/2024', 'Jumlah Pembelian': 19}, {'ID': 'TRX000004', 'Nama Pelanggan': 'drg. Mumpuni Lazuardi, S.T.', 'Tanggal Pembelian': '02/02/2025', 'Jumlah Pembelian': 10}, {'ID': 'TRX000005', 'Nama Pelanggan': 'Ganep Zulaika', 'Tanggal Pembelian': '29/08/2024', 'Jumlah Pembelian': 3}]
# ...
# Waktu Hash-Bubble: 0.433957 detik
# Ruang Memori: 81208 bytes
#
# [6] Hash-Selection (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 'TRX002149', 'Nama Pelanggan': 'Cindy Puspasari', 'Tanggal Pembelian': '11/06/2024', 'Jumlah Pembelian': 1}, {'ID': 'TRX006533', 'Nama Pelanggan': 'Salsabila Laksita', 'Tanggal Pembelian': '05/01/2025', 'Jumlah Pembelian': 1}, {'ID': 'TRX009502', 'Nama Pelanggan': 'Purwanto Kusmawati', 'Tanggal Pembelian': '27/06/2024', 'Jumlah Pembelian': 1}, {'ID': 'TRX003879', 'Nama Pelanggan': 'Taufan Hutagalung', 'Tanggal Pembelian': '26/07/2024', 'Jumlah Pembelian': 1}, {'ID': 'TRX006052', 'Nama Pelanggan': 'Dadap Sihombing', 'Tanggal Pembelian': '18/10/2024', 'Jumlah Pembelian': 1}]
# Waktu Hash-Selection: 0.415749 detik
# Ruang Memori: 81208 bytes
#
# [7] Jump-Bubble (by Jumlah Pembelian)...
# Hasil: []
# Waktu Jump-Bubble: 13.532077 detik
# Ruang Memori: 85176 bytes
#
# [8] Jump-Selection (by Jumlah Pembelian)...
# Hasil: []
# Waktu Jump-Selection: 9.980559 detik
# Ruang Memori: 85176 bytes
#
# ================== MEMUAT DATASET: dataset_tiruan.xlsx ==================
# Kolom asli: ['ID', 'Nama Pelanggan', 'Tanggal Pembelian', 'Jumlah Pembelian']
# ⚠️ 6073 baris dengan nilai kosong di kolom kunci: [{'ID': 2, 'Nama Pelanggan': 'Gregory Rodriguez', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 892}, {'ID': 4, 'Nama Pelanggan': 'Jordan Williams', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 725}, {'ID': 7, 'Nama Pelanggan': 'Susan Sampson', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 358}, {'ID': 8, 'Nama Pelanggan': 'Jessica Williams', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 49}, {'ID': 9, 'Nama Pelanggan': 'Colleen Johnson', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 784}]
# ✅ Jumlah Data: 3927
# Contoh Data (5 data pertama):
# {'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880}
# {'ID': 3, 'Nama Pelanggan': 'Jessica Allen', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 983}
# {'ID': 5, 'Nama Pelanggan': 'Jordan Brown', 'Tanggal Pembelian': '02/01/2022', 'Jumlah Pembelian': 847}
# {'ID': 6, 'Nama Pelanggan': 'Jordan Sampson', 'Tanggal Pembelian': '12/03/2022', 'Jumlah Pembelian': 715}
# {'ID': 10, 'Nama Pelanggan': 'Susan Sampson', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 377}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID ---
#
# [1] Hash Search (by ID)...
# Hasil: [{'ID': 30, 'Nama Pelanggan': 'Michael Johnson', 'Tanggal Pembelian': '01/06/2022', 'Jumlah Pembelian': 459}]
# Waktu Hash Search: 0.000814 detik
# Ruang Memori: 147544 bytes
#
# [2] Jump Search (by ID)...
# Hasil: [{'ID': 30, 'Nama Pelanggan': 'Michael Johnson', 'Tanggal Pembelian': '01/06/2022', 'Jumlah Pembelian': 459}]
# Waktu Jump Search: 0.000010 detik
# Ruang Memori: 31480 bytes
#
# [3] Bubble Sort (by ID)...
# Hasil (5 data pertama): [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880}, {'ID': 3, 'Nama Pelanggan': 'Jessica Allen', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 983}, {'ID': 5, 'Nama Pelanggan': 'Jordan Brown', 'Tanggal Pembelian': '02/01/2022', 'Jumlah Pembelian': 847}, {'ID': 6, 'Nama Pelanggan': 'Jordan Sampson', 'Tanggal Pembelian': '12/03/2022', 'Jumlah Pembelian': 715}, {'ID': 10, 'Nama Pelanggan': 'Susan Sampson', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 377}]
# Waktu Bubble Sort: 1.259797 detik
# Ruang Memori: 31472 bytes
#
# [4] Selection Sort (by ID)...
# Hasil (5 data pertama): [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880}, {'ID': 3, 'Nama Pelanggan': 'Jessica Allen', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 983}, {'ID': 5, 'Nama Pelanggan': 'Jordan Brown', 'Tanggal Pembelian': '02/01/2022', 'Jumlah Pembelian': 847}, {'ID': 6, 'Nama Pelanggan': 'Jordan Sampson', 'Tanggal Pembelian': '12/03/2022', 'Jumlah Pembelian': 715}, {'ID': 10, 'Nama Pelanggan': 'Susan Sampson', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 377}]
# Waktu Selection Sort: 1.042119 detik
# Ruang Memori: 31472 bytes
#
# [5] Hash-Bubble (by ID)...
# Hasil (5 data pertama): [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880}, {'ID': 3, 'Nama Pelanggan': 'Jessica Allen', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 983}, {'ID': 5, 'Nama Pelanggan': 'Jordan Brown', 'Tanggal Pembelian': '02/01/2022', 'Jumlah Pembelian': 847}, {'ID': 6, 'Nama Pelanggan': 'Jordan Sampson', 'Tanggal Pembelian': '12/03/2022', 'Jumlah Pembelian': 715}, {'ID': 10, 'Nama Pelanggan': 'Susan Sampson', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 377}]
# Waktu Hash-Bubble: 0.002927 detik
# Ruang Memori: 33048 bytes
#
# [6] Hash-Selection (by ID)...
# Hasil (5 data pertama): [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880}, {'ID': 3, 'Nama Pelanggan': 'Jessica Allen', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 983}, {'ID': 5, 'Nama Pelanggan': 'Jordan Brown', 'Tanggal Pembelian': '02/01/2022', 'Jumlah Pembelian': 847}, {'ID': 6, 'Nama Pelanggan': 'Jordan Sampson', 'Tanggal Pembelian': '12/03/2022', 'Jumlah Pembelian': 715}, {'ID': 10, 'Nama Pelanggan': 'Susan Sampson', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 377}]
# Waktu Hash-Selection: 0.002851 detik
# Ruang Memori: 33048 bytes
#
# [7] Jump-Bubble (by ID)...
# Hasil: [{'ID': 30, 'Nama Pelanggan': 'Michael Johnson', 'Tanggal Pembelian': '01/06/2022', 'Jumlah Pembelian': 459}]
# Waktu Jump-Bubble: 1.471906 detik
# Ruang Memori: 33048 bytes
#
# [8] Jump-Selection (by ID)...
# Hasil: [{'ID': 30, 'Nama Pelanggan': 'Michael Johnson', 'Tanggal Pembelian': '01/06/2022', 'Jumlah Pembelian': 459}]
# Waktu Jump-Selection: 1.986374 detik
# Ruang Memori: 33048 bytes
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Hash Search (by Nama Pelanggan)...
# Hasil: []
# Waktu Hash Search: 0.001186 detik
# Ruang Memori: 3328 bytes
#
# [2] Jump Search (by Nama Pelanggan)...
# Hasil: []
# Waktu Jump Search: 0.000044 detik
# Ruang Memori: 31480 bytes
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 270, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '08/11/2022', 'Jumlah Pembelian': 971}, {'ID': 801, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '06/12/2022', 'Jumlah Pembelian': 203}, {'ID': 1551, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '11/07/2022', 'Jumlah Pembelian': 99}, {'ID': 2080, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '10/02/2022', 'Jumlah Pembelian': 471}, {'ID': 2121, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '11/03/2022', 'Jumlah Pembelian': 101}]
# Waktu Bubble Sort: 2.215540 detik
# Ruang Memori: 31472 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 270, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '08/11/2022', 'Jumlah Pembelian': 971}, {'ID': 801, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '06/12/2022', 'Jumlah Pembelian': 203}, {'ID': 1551, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '11/07/2022', 'Jumlah Pembelian': 99}, {'ID': 2080, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '10/02/2022', 'Jumlah Pembelian': 471}, {'ID': 2121, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '11/03/2022', 'Jumlah Pembelian': 101}]
# Waktu Selection Sort: 1.367553 detik
# Ruang Memori: 31472 bytes
#
# [5] Hash-Bubble (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 270, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '08/11/2022', 'Jumlah Pembelian': 971}, {'ID': 801, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '06/12/2022', 'Jumlah Pembelian': 203}, {'ID': 1551, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '11/07/2022', 'Jumlah Pembelian': 99}, {'ID': 2080, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '10/02/2022', 'Jumlah Pembelian': 471}, {'ID': 2121, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '11/03/2022', 'Jumlah Pembelian': 101}]
# Waktu Hash-Bubble: 0.014468 detik
# Ruang Memori: 34264 bytes
#
# [6] Hash-Selection (by Nama Pelanggan)...
# Hasil (5 data pertama): [{'ID': 270, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '08/11/2022', 'Jumlah Pembelian': 971}, {'ID': 801, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '06/12/2022', 'Jumlah Pembelian': 203}, {'ID': 1551, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '11/07/2022', 'Jumlah Pembelian': 99}, {'ID': 2080, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '10/02/2022', 'Jumlah Pembelian': 471}, {'ID': 2121, 'Nama Pelanggan': 'Andrea Allen', 'Tanggal Pembelian': '11/03/2022', 'Jumlah Pembelian': 101}]
# Waktu Hash-Selection: 0.013149 detik
# Ruang Memori: 34264 bytes
#
# [7] Jump-Bubble (by Nama Pelanggan)...
# Hasil: []
# Waktu Jump-Bubble: 1.800957 detik
# Ruang Memori: 33048 bytes
#
# [8] Jump-Selection (by Nama Pelanggan)...
# Hasil: []
# Waktu Jump-Selection: 1.366180 detik
# Ruang Memori: 33048 bytes
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Hash Search (by Tanggal Pembelian)...
# Hasil: []
# Waktu Hash Search: 0.000730 detik
# Ruang Memori: 3328 bytes
#
# [2] Jump Search (by Tanggal Pembelian)...
# Hasil: []
# Waktu Jump Search: 0.000015 detik
# Ruang Memori: 31480 bytes
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 277, 'Nama Pelanggan': 'Gregory Smith', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 793}, {'ID': 756, 'Nama Pelanggan': 'Jessica Sampson', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 407}, {'ID': 1112, 'Nama Pelanggan': 'Colleen Rodriguez', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 972}, {'ID': 1447, 'Nama Pelanggan': 'Sarah Simpson', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 944}, {'ID': 2550, 'Nama Pelanggan': 'Michael Brown', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 644}]
# Waktu Bubble Sort: 1.953120 detik
# Ruang Memori: 31472 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 277, 'Nama Pelanggan': 'Gregory Smith', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 793}, {'ID': 756, 'Nama Pelanggan': 'Jessica Sampson', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 407}, {'ID': 1112, 'Nama Pelanggan': 'Colleen Rodriguez', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 972}, {'ID': 1447, 'Nama Pelanggan': 'Sarah Simpson', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 944}, {'ID': 2550, 'Nama Pelanggan': 'Michael Brown', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 644}]
# Waktu Selection Sort: 1.404874 detik
# Ruang Memori: 31472 bytes
#
# [5] Hash-Bubble (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 277, 'Nama Pelanggan': 'Gregory Smith', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 793}, {'ID': 756, 'Nama Pelanggan': 'Jessica Sampson', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 407}, {'ID': 1112, 'Nama Pelanggan': 'Colleen Rodriguez', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 972}, {'ID': 1447, 'Nama Pelanggan': 'Sarah Simpson', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 944}, {'ID': 2550, 'Nama Pelanggan': 'Michael Brown', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 644}]
# Waktu Hash-Bubble: 0.011274 detik
# Ruang Memori: 31896 bytes
#
# [6] Hash-Selection (by Tanggal Pembelian)...
# Hasil (5 data pertama): [{'ID': 277, 'Nama Pelanggan': 'Gregory Smith', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 793}, {'ID': 756, 'Nama Pelanggan': 'Jessica Sampson', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 407}, {'ID': 1112, 'Nama Pelanggan': 'Colleen Rodriguez', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 972}, {'ID': 1447, 'Nama Pelanggan': 'Sarah Simpson', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 944}, {'ID': 2550, 'Nama Pelanggan': 'Michael Brown', 'Tanggal Pembelian': '01/01/2022', 'Jumlah Pembelian': 644}]
# Waktu Hash-Selection: 0.010130 detik
# Ruang Memori: 31896 bytes
#
# [7] Jump-Bubble (by Tanggal Pembelian)...
# Hasil: []
# Waktu Jump-Bubble: 3.184130 detik
# Ruang Memori: 33048 bytes
#
# [8] Jump-Selection (by Tanggal Pembelian)...
# Hasil: []
# Waktu Jump-Selection: 1.682043 detik
# Ruang Memori: 33048 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Hash Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Hash Search: 0.000876 detik
# Ruang Memori: 36952 bytes
#
# [2] Jump Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Jump Search: 0.000028 detik
# Ruang Memori: 31480 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 400, 'Nama Pelanggan': 'Jordan Rodriguez', 'Tanggal Pembelian': '02/11/2022', 'Jumlah Pembelian': 1}, {'ID': 965, 'Nama Pelanggan': 'Jessica Allen', 'Tanggal Pembelian': '01/12/2022', 'Jumlah Pembelian': 1}, {'ID': 7106, 'Nama Pelanggan': 'Anthony Williams', 'Tanggal Pembelian': '03/01/2022', 'Jumlah Pembelian': 1}, {'ID': 7842, 'Nama Pelanggan': 'Colleen Rodriguez', 'Tanggal Pembelian': '04/11/2022', 'Jumlah Pembelian': 1}, {'ID': 9435, 'Nama Pelanggan': 'Susan Johnson', 'Tanggal Pembelian': '07/03/2022', 'Jumlah Pembelian': 1}]
# Waktu Bubble Sort: 1.777870 detik
# Ruang Memori: 31472 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 400, 'Nama Pelanggan': 'Jordan Rodriguez', 'Tanggal Pembelian': '02/11/2022', 'Jumlah Pembelian': 1}, {'ID': 965, 'Nama Pelanggan': 'Jessica Allen', 'Tanggal Pembelian': '01/12/2022', 'Jumlah Pembelian': 1}, {'ID': 7106, 'Nama Pelanggan': 'Anthony Williams', 'Tanggal Pembelian': '03/01/2022', 'Jumlah Pembelian': 1}, {'ID': 7842, 'Nama Pelanggan': 'Colleen Rodriguez', 'Tanggal Pembelian': '04/11/2022', 'Jumlah Pembelian': 1}, {'ID': 9435, 'Nama Pelanggan': 'Susan Johnson', 'Tanggal Pembelian': '07/03/2022', 'Jumlah Pembelian': 1}]
# Waktu Selection Sort: 1.280343 detik
# Ruang Memori: 31472 bytes
#
# [5] Hash-Bubble (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 400, 'Nama Pelanggan': 'Jordan Rodriguez', 'Tanggal Pembelian': '02/11/2022', 'Jumlah Pembelian': 1}, {'ID': 965, 'Nama Pelanggan': 'Jessica Allen', 'Tanggal Pembelian': '01/12/2022', 'Jumlah Pembelian': 1}, {'ID': 7106, 'Nama Pelanggan': 'Anthony Williams', 'Tanggal Pembelian': '03/01/2022', 'Jumlah Pembelian': 1}, {'ID': 7842, 'Nama Pelanggan': 'Colleen Rodriguez', 'Tanggal Pembelian': '04/11/2022', 'Jumlah Pembelian': 1}, {'ID': 9435, 'Nama Pelanggan': 'Susan Johnson', 'Tanggal Pembelian': '07/03/2022', 'Jumlah Pembelian': 1}]
# Waktu Hash-Bubble: 0.003321 detik
# Ruang Memori: 31576 bytes
#
# [6] Hash-Selection (by Jumlah Pembelian)...
# Hasil (5 data pertama): [{'ID': 400, 'Nama Pelanggan': 'Jordan Rodriguez', 'Tanggal Pembelian': '02/11/2022', 'Jumlah Pembelian': 1}, {'ID': 965, 'Nama Pelanggan': 'Jessica Allen', 'Tanggal Pembelian': '01/12/2022', 'Jumlah Pembelian': 1}, {'ID': 7106, 'Nama Pelanggan': 'Anthony Williams', 'Tanggal Pembelian': '03/01/2022', 'Jumlah Pembelian': 1}, {'ID': 7842, 'Nama Pelanggan': 'Colleen Rodriguez', 'Tanggal Pembelian': '04/11/2022', 'Jumlah Pembelian': 1}, {'ID': 9435, 'Nama Pelanggan': 'Susan Johnson', 'Tanggal Pembelian': '07/03/2022', 'Jumlah Pembelian': 1}]
# Waktu Hash-Selection: 0.003556 detik
# Ruang Memori: 31576 bytes
#
# [7] Jump-Bubble (by Jumlah Pembelian)...
# Hasil: []
# Waktu Jump-Bubble: 1.781552 detik
# Ruang Memori: 33048 bytes
#
# [8] Jump-Selection (by Jumlah Pembelian)...
# Hasil: []
# Waktu Jump-Selection: 1.298836 detik
# Ruang Memori: 33048 bytes

# %%
import pandas as pd
import math
import time

# Fungsi untuk ekstrak ID numerik dari string
def extract_numeric_id(id_str):
    try:
        return int(id_str.replace("TRX", ""))
    except:
        return -1  # Tangani ID tidak valid

# Fungsi Jump Search (as found in the original notebook)
# This function expects a sorted list/array of numeric values
def jump_search(arr, target):
    n = len(arr)
    if n == 0: # Handle empty array case
        return -1
    step = int(math.sqrt(n))
    prev = 0
    # Find the block where target might be present
    while prev < n and arr[min(step, n) - 1] < target:
        prev = step
        step += int(math.sqrt(n))
        if prev >= n:
            return -1 # Target is beyond the last block

    # Perform linear search within the block
    while prev < min(step, n): # Iterate up to the block boundary
        if arr[prev] == target:
            return prev # Target found
        prev += 1

    return -1 # Target not found

# Fungsi Jump-Bubble Sort (as found in the original notebook)
# This function expects a list of dictionaries and a key
def jump_bubble_sort(arr, key):
    n = len(arr)
    if n == 0:
        return arr
    step = int(math.sqrt(n))
    swapped = True
    # Perform jump swaps
    while swapped:
        swapped = False
        for i in range(0, n-step):
             # Ensure keys exist and values are comparable
            val1 = arr[i].get(key)
            val2 = arr[i+step].get(key)
            # Handle None or incomparable types gracefully
            if val1 is not None and val2 is not None:
                 # Attempt comparison, handle potential TypeError
                 try:
                     if val1 > val2:
                         arr[i], arr[i+step] = arr[i+step], arr[i]
                         swapped = True
                 except TypeError:
                     print(f"Warning: Cannot compare values for key '{key}' at indices {i} and {i+step}. Skipping swap.")


    # Bubble sort standard for remaining elements within blocks
    # This part seems inefficient and potentially incorrect for jump-bubble logic.
    # A typical jump-bubble would refine sorts within blocks or use a smaller step size.
    # However, based on the provided code's apparent intent:
    # Perform a final bubble sort on the partially sorted array
    for i in range(n-1):
        for j in range(0, n-i-1):
             # Ensure keys exist and values are comparable
            val1 = arr[j].get(key)
            val2 = arr[j+1].get(key)
            if val1 is not None and val2 is not None:
                try:
                    if val1 > val2:
                        arr[j], arr[j+1] = arr[j+1], arr[j]
                except TypeError:
                     print(f"Warning: Cannot compare values for key '{key}' at indices {j} and {j+1}. Skipping swap.")
    return arr


# Fungsi Jump-Selection Sort (as found in the original notebook)
# This function expects a list of dictionaries and a key
def jump_selection_sort(arr, key):
    n = len(arr)
    if n == 0:
        return arr
    step = int(math.sqrt(n))
    for i in range(n):
        min_idx = i
        # Find minimum within jump steps
        for j in range(i+step, n, step):
            # Ensure keys exist and values are comparable
            val_j = arr[j].get(key)
            val_min = arr[min_idx].get(key)
            if val_j is not None and val_min is not None:
                 try:
                     if val_j < val_min:
                         min_idx = j
                 except TypeError:
                    print(f"Warning: Cannot compare values for key '{key}' at index {j} and {min_idx}. Skipping comparison.")

        # Periksa sisa elemen dalam langkah (linear scan in the final block or refine search)
        # This part is also unusual for a standard jump-selection.
        # It seems to perform a linear scan up to the next step boundary after finding a jump-based minimum.
        # A more standard approach might be to find the minimum in the block starting at i.
        # Based on the provided code's apparent intent:
        # Check elements between i and the next step boundary for the minimum
        for j in range(i+1, min(i+step, n)):
             # Ensure keys exist and values are comparable
            val_j = arr[j].get(key)
            val_min = arr[min_idx].get(key)
            if val_j is not None and val_min is not None:
                 try:
                    if val_j < val_min:
                        min_idx = j
                 except TypeError:
                    print(f"Warning: Cannot compare values for key '{key}' at index {j} and {min_idx}. Skipping comparison.")

        # Swap the found minimum with the element at index i
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr


# Fungsi untuk memproses dan menjalankan algoritma
def process_dataset(dataset_path, dataset_name):
    print(f"\nMemproses {dataset_name}")

    try:
        # Baca dataset
        if dataset_path.endswith('.xlsx'):
             df = pd.read_excel(dataset_path)
        else:
             df = pd.read_csv(dataset_path)

        # Normalisasi nama kolom (sesuai dengan logika di kode sebelumnya)
        df.columns = [col.strip() for col in df.columns]
        df = normalize_columns(df, dataset_name) # Use the previously defined normalize_columns

        # Ensure required columns exist after normalization
        expected_cols = ['ID', 'Nama Pelanggan', 'Tanggal Pembelian', 'Jumlah Pembelian']
        if not all(col in df.columns for col in expected_cols):
             missing = [col for col in expected_cols if col not in df.columns]
             print(f"❌ Skipping {dataset_name}: Missing expected columns after normalization: {missing}")
             print(f"Available columns: {list(df.columns)}")
             return # Skip if columns are not as expected

        # Select and process relevant columns
        df = df[expected_cols].copy()

        # Convert 'Jumlah Pembelian' to numeric, coercing errors
        df['Jumlah Pembelian'] = pd.to_numeric(df['Jumlah Pembelian'], errors='coerce')

        # Ensure 'ID' column exists before attempting to extract numeric ID
        if 'ID' not in df.columns:
             print(f"❌ Skipping {dataset_name}: 'ID' column not found after normalization. Cannot proceed with ID-based search/sort.")
             return

        # Extract numeric ID only if the column exists
        # Handle potential non-string IDs or missing IDs before applying replace
        df['ID_Numeric'] = df['ID'].apply(lambda x: extract_numeric_id(str(x)) if pd.notna(x) else -1)

        # Drop rows where critical columns are missing after conversion/extraction
        # For data_transaksi.csv, exclude ID from essential dropna subset based on previous logic
        subset_cols_for_dropna = ['Nama Pelanggan', 'Tanggal Pembelian', 'Jumlah Pembelian']
        if dataset_name != 'data_transaksi.csv':
             subset_cols_for_dropna.append('ID') # Include ID for other datasets if needed

        # Ensure columns exist before dropping
        subset_cols_for_dropna = [col for col in subset_cols_for_dropna if col in df.columns]

        if subset_cols_for_dropna:
             initial_rows = len(df)
             df.dropna(subset=subset_cols_for_dropna, inplace=True)
             if len(df) < initial_rows:
                 print(f"⚠️ Dropped {initial_rows - len(df)} rows with missing values in {subset_cols_for_dropna}.")

        # Check for invalid ID_Numeric values after dropping rows
        if (df['ID_Numeric'] == -1).any():
            print(f"⚠️ {dataset_name}: Terdapat ID tidak valid (-1) setelah pemrosesan. Baris ini mungkin akan memengaruhi hasil pencarian/pengurutan berbasis ID.")
            # Option: df = df[df['ID_Numeric'] != -1].copy() # Uncomment if you want to remove these rows

        # Convert to list of dictionaries for custom algorithms
        data_list = df.to_dict('records')

        # Proceed only if there is data after cleaning
        if not data_list:
            print(f"⚠️ No valid data remaining in {dataset_name} after processing. Skipping algorithms.")
            return

        print(f"✅ Processed data count: {len(data_list)}")

        # 1. Jump Search (by ID_Numeric)
        # Jump search as implemented here expects a sorted list of *numeric* values
        # So we need to sort by 'ID_Numeric' first and pass only the numeric IDs.
        print("\nMenjalankan Jump Search (by ID_Numeric)...")
        # Sort data_list by ID_Numeric to prepare for Jump Search on the numeric IDs
        sorted_data_list_id_numeric = sorted(data_list, key=lambda x: x.get('ID_Numeric', -1)) # Use -1 for None/missing ID_Numeric
        id_numeric_values = [item.get('ID_Numeric', -1) for item in sorted_data_list_id_numeric] # Extract only the numeric IDs

        # Define target ID_Numeric based on the dataset
        target_id_numeric = None
        if dataset_name == 'data_transaksi.csv':
             # Assuming 'data_transaksi.csv' IDs are like TRX1, TRX2...
             # Let's pick a sample numeric ID. Find one from the actual data if possible.
             if id_numeric_values:
                 sample_ids = [id for id in id_numeric_values if id != -1][:5] # Get some valid sample IDs
                 if sample_ids:
                    target_id_numeric = sample_ids[0] # Use the first valid sample as target
                    print(f"Using sample target ID_Numeric for {dataset_name}: {target_id_numeric}")
                 else:
                    print(f"Warning: No valid numeric IDs found in {dataset_name} to set target.")
                    target_id_numeric = 1 # Default if no valid samples found
            # Adjust target if needed based on actual data range
        elif dataset_name == 'Dataset Penjualan Buku.csv':
             # Assuming 'Dataset Penjualan Buku.csv' has integer IDs directly mappable
             if id_numeric_values:
                 sample_ids = [id for id in id_numeric_values if id != -1][:5]
                 if sample_ids:
                    target_id_numeric = sample_ids[0]
                    print(f"Using sample target ID_Numeric for {dataset_name}: {target_id_numeric}")
                 else:
                    print(f"Warning: No valid numeric IDs found in {dataset_name} to set target.")
                    target_id_numeric = 1 # Default
        else:
            print(f"Warning: No specific target ID_Numeric defined for {dataset_name}. Using default target 1.")
            target_id_numeric = 1 # Default target for other datasets

        if target_id_numeric is not None:
            start_time = time.time()
            # Perform jump search on the list of numeric IDs
            result_index = jump_search(id_numeric_values, target_id_numeric)
            end_time = time.time()

            if result_index != -1:
                # Retrieve the original dictionary using the index from the sorted numeric list
                original_data_item = sorted_data_list_id_numeric[result_index]
                print(f"ID_Numeric {target_id_numeric} found at index {result_index} in the sorted numeric list.")
                print(f"Corresponding original data item: {original_data_item}")
            else:
                print(f"ID_Numeric {target_id_numeric} not found")
            print(f"Waktu eksekusi Jump Search (by ID_Numeric): {end_time - start_time:.6f} detik")
        else:
            print("Skipping Jump Search (by ID_Numeric) due to no valid target.")

        # 2. Jump-Bubble (by ID_Numeric)
        print("\nMenjalankan Jump-Bubble (by ID_Numeric)...")
        start_time = time.time()
        # Pass a copy of the data_list to jump_bubble_sort
        sorted_data_jb = jump_bubble_sort(data_list.copy(), 'ID_Numeric')
        end_time = time.time()
        # Print the ID_Numeric for the first few elements of the sorted list
        print(f"5 baris pertama setelah pengurutan Jump-Bubble: {[row.get('ID_Numeric', 'N/A') for row in sorted_data_jb[:5]]}")
        print(f"Waktu eksekusi Jump-Bubble: {end_time - start_time:.6f} detik")

        # 3. Jump-Selection (by ID_Numeric)
        print("\nMenjalankan Jump-Selection (by ID_Numeric)...")
        start_time = time.time()
        # Pass a copy of the data_list to jump_selection_sort
        sorted_data_js = jump_selection_sort(data_list.copy(), 'ID_Numeric')
        end_time = time.time()
        # Print the ID_Numeric for the first few elements of the sorted list
        print(f"5 baris pertama setelah pengurutan Jump-Selection: {[row.get('ID_Numeric', 'N/A') for row in sorted_data_js[:5]]}")
        print(f"Waktu eksekusi Jump-Selection: {end_time - start_time:.6f} detik")

    except FileNotFoundError:
        print(f"❌ Gagal memproses dataset {dataset_name}: File tidak ditemukan di lokasi: {dataset_path}")
    except Exception as e:
        print(f"❌ Gagal memproses dataset {dataset_name}: {e}")


# Define all_datasets dictionary as it was in the working notebook context
github_datasets = {
    'penjualan barang.csv': 'https://raw.githubusercontent.com/Anggunsky/datasetPenjualan/main/penjualan%20barang.csv',
    'data_transaksi.csv': 'https://raw.githubusercontent.com/annisareida/Benchmarking-Algoritma/main/data_transaksi.csv',
}
drive_datasets = {
    'synthetic (1).csv': '/content/drive/MyDrive/DATASET/synthetic (1).csv',
    'Dataset Penjualan Buku.csv': '/content/drive/MyDrive/DATASET/Dataset Penjualan Buku.csv',
    'dataset_tiruan.xlsx': '/content/drive/MyDrive/DATASET/dataset_tiruan.xlsx'
}
all_datasets = {**github_datasets, **drive_datasets}


# Jalankan untuk kedua dataset menggunakan paths dari all_datasets
# Make sure the keys used here match the keys in all_datasets
if 'data_transaksi.csv' in all_datasets:
    process_dataset(all_datasets['data_transaksi.csv'], "data_transaksi.csv")
else:
    print("❌ 'data_transaksi.csv' not found in all_datasets.")

if 'Dataset Penjualan Buku.csv' in all_datasets:
    process_dataset(all_datasets['Dataset Penjualan Buku.csv'], "Dataset Penjualan Buku.csv")
else:
    print("❌ 'Dataset Penjualan Buku.csv' not found in all_datasets.")
# Out:
# Memproses data_transaksi.csv
# ✅ Processed data count: 10000
#
# Menjalankan Jump Search (by ID_Numeric)...
# Using sample target ID_Numeric for data_transaksi.csv: 0
# ID_Numeric 0 found at index 0 in the sorted numeric list.
# Corresponding original data item: {'ID': 'TRX00000', 'Nama Pelanggan': 'OMODF', 'Tanggal Pembelian': '2024-10-28', 'Jumlah Pembelian': 839.53, 'ID_Numeric': 0}
# Waktu eksekusi Jump Search (by ID_Numeric): 0.000008 detik
#
# Menjalankan Jump-Bubble (by ID_Numeric)...
# 5 baris pertama setelah pengurutan Jump-Bubble: [0, 1, 2, 3, 4]
# Waktu eksekusi Jump-Bubble: 7.396053 detik
#
# Menjalankan Jump-Selection (by ID_Numeric)...
# 5 baris pertama setelah pengurutan Jump-Selection: [0, 1, 2, 3, 4]
# Waktu eksekusi Jump-Selection: 0.199380 detik
#
# Memproses Dataset Penjualan Buku.csv
# ✅ Processed data count: 10000
#
# Menjalankan Jump Search (by ID_Numeric)...
# Using sample target ID_Numeric for Dataset Penjualan Buku.csv: 1
# ID_Numeric 1 found at index 0 in the sorted numeric list.
# Corresponding original data item: {'ID': 'TRX000001', 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '2025-04-14', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}
# Waktu eksekusi Jump Search (by ID_Numeric): 0.000006 detik
#
# Menjalankan Jump-Bubble (by ID_Numeric)...
# 5 baris pertama setelah pengurutan Jump-Bubble: [1, 2, 3, 4, 5]
# Waktu eksekusi Jump-Bubble: 10.185885 detik
#
# Menjalankan Jump-Selection (by ID_Numeric)...
# 5 baris pertama setelah pengurutan Jump-Selection: [56, 94, 81, 32, 78]
# Waktu eksekusi Jump-Selection: 0.202862 detik

# %% [markdown]
# # BENCHMARKING YANG DIPERBARUI

# %%
# import library di collab
import time
import pandas as pd
import sys
import os
from google.colab import drive
from IPython.display import display

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Dataset paths
github_datasets = {
    'penjualan barang.csv': 'https://raw.githubusercontent.com/Anggunsky/datasetPenjualan/main/penjualan%20barang.csv',
    'data_transaksi.csv': 'https://raw.githubusercontent.com/annisareida/Benchmarking-Algoritma/main/data_transaksi.csv',
}
drive_datasets = {
    'synthetic (1).csv': '/content/drive/MyDrive/DATASET/synthetic (1).csv',
    'Dataset Penjualan Buku.csv': '/content/drive/MyDrive/DATASET/Dataset Penjualan Buku.csv',
    'dataset_tiruan.xlsx': '/content/drive/MyDrive/DATASET/dataset_tiruan.xlsx',
    }
all_datasets = {**github_datasets, **drive_datasets}

# %%
# FUNCTION UTILITIES
def extract_numeric_id(id_str):
    try:
        if isinstance(id_str, str) and id_str.startswith('TRX'):
            return int(id_str.replace('TRX', ''))
        return int(id_str)  # Untuk ID numerik langsung
    except:
        return -1  # Tangani ID tidak valid

# %%
# Fungsi Sequence Search
def sequence_search(data, key, target):
    for i, item in enumerate(data):
        if item.get(key) == target:
            return [item]  # Return as list for consistency
    return []

# %%
# Fungsi Binary Search
def binary_search(data, key, target):
    left, right = 0, len(data) - 1
    while left <= right:
        mid = (left + right) // 2
        if data[mid].get(key) == target:
            return [data[mid]]  # Return as list for consistency
        elif data[mid].get(key) < target:
            left = mid + 1
        else:
            right = mid - 1
    return []

# %%
# Fungsi Bubble Sort
def bubble_sort(data, key):
    data_copy = data[:]
    n = len(data_copy)
    for i in range(n):
        swapped = False
        for j in range(0, n - i - 1):
            if (data_copy[j].get(key) is not None and
                data_copy[j + 1].get(key) is not None and
                data_copy[j][key] > data_copy[j + 1][key]):
                data_copy[j], data_copy[j + 1] = data_copy[j + 1], data_copy[j]
                swapped = True
        if not swapped:
            break
    return data_copy

# %%
# Fungsi Selection Sort
def selection_sort(data, key):
    data_copy = data[:]
    n = len(data_copy)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if (data_copy[j].get(key) is not None and
                data_copy[min_idx].get(key) is not None and
                data_copy[j][key] < data_copy[min_idx][key]):
                min_idx = j
        data_copy[i], data_copy[min_idx] = data_copy[min_idx], data_copy[i]
    return data_copy

# %%
# Fungsi Sequence-Bubble (Bubble Sort dengan Sequence Search untuk verifikasi)
def sequence_bubble(data, key, target):
    search_result = sequence_search(data, key, target)
    print(f"Sequence Search sebelum Bubble Sort: {search_result[:5] if search_result else 'Tidak ditemukan'}")
    return bubble_sort(data, key)

# %%
# Fungsi Sequence-Selection (Selection Sort dengan Sequence Search untuk verifikasi)
def sequence_selection(data, key, target):
    search_result = sequence_search(data, key, target)
    print(f"Sequence Search sebelum Selection Sort: {search_result[:5] if search_result else 'Tidak ditemukan'}")
    return selection_sort(data, key)

# %%
# Fungsi Binary-Bubble (Bubble Sort dengan Binary Search untuk verifikasi)
def binary_bubble(data, key, target):
    sorted_data = sorted(data, key=lambda x: x.get(key, 0))
    search_result = binary_search(sorted_data, key, target)
    print(f"Binary Search sebelum Bubble Sort: {search_result[:5] if search_result else 'Tidak ditemukan'}")
    return bubble_sort(data, key)

# %%
# Fungsi Binary-Selection (Selection Sort dengan Binary Search untuk verifikasi)
def binary_selection(data, key, target):
    sorted_data = sorted(data, key=lambda x: x.get(key, 0))
    search_result = binary_search(sorted_data, key, target)
    print(f"Binary Search sebelum Selection Sort: {search_result[:5] if search_result else 'Tidak ditemukan'}")
    return selection_sort(data, key)

# %%
def memory_complexity(data):
    return sys.getsizeof(data)

# %%
# BENCHMARKING FUNCTION
def benchmark(transactions):
    print("\n==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================")

    keys = ['ID_Numeric', 'Jumlah Pembelian', 'Nama Pelanggan', 'Tanggal Pembelian']
    search_targets = {
        'ID_Numeric': 1,
        'Jumlah Pembelian': 1000.0,  # Contoh, sesuaikan dengan data
        'Nama Pelanggan': 'TOKO HERUNIAWATI',  # Contoh, sesuaikan
        'Tanggal Pembelian': '01/01/2020'  # Contoh, sesuaikan
    }

    for key in keys:
        print(f"\n--- Benchmarking untuk Kolom: {key} ---")

        # Sequence Search
        print(f"\n[1] Sequence Search (by {key})...")
        start = time.time()
        result = sequence_search(transactions, key, search_targets[key])
        end = time.time()
        print(f"Hasil: {result[:5]}" if len(result) > 5 else f"Hasil: {result}")
        print(f"Waktu Sequence Search: {end - start:.6f} detik")
        print(f"Ruang Memori: {memory_complexity(transactions)} bytes")

        # Binary Search (hanya untuk kolom numerik)
        if key in ['ID_Numeric', 'Jumlah Pembelian']:
            print(f"\n[2] Binary Search (by {key})...")
            try:
                sorted_txn = sorted(transactions, key=lambda x: x.get(key, 0))
                start = time.time()
                result = binary_search(sorted_txn, key, search_targets[key])
                end = time.time()
                print(f"Hasil: {result[:5]}" if len(result) > 5 else f"Hasil: {result}")
                print(f"Waktu Binary Search: {end - start:.6f} detik")
                print(f"Ruang Memori: {memory_complexity(sorted_txn)} bytes")
            except TypeError as e:
                print(f"⚠️ Binary Search (by {key}) gagal karena masalah tipe data: {e}")
        else:
            print(f"\n[2] Binary Search (by {key}) dilewati karena kolom bukan numerik")

        # Bubble Sort
        print(f"\n[3] Bubble Sort (by {key})...")
        try:
            start = time.time()
            sorted_data = bubble_sort(transactions, key)
            end = time.time()
            print(f"Hasil (5 data pertama): {[item[key] for item in sorted_data[:5]]}")
            print(f"Waktu Bubble Sort: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Bubble Sort (by {key}) gagal karena masalah tipe data: {e}")

        # Selection Sort
        print(f"\n[4] Selection Sort (by {key})...")
        try:
            start = time.time()
            sorted_data = selection_sort(transactions, key)
            end = time.time()
            print(f"Hasil (5 data pertama): {[item[key] for item in sorted_data[:5]]}")
            print(f"Waktu Selection Sort: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Selection Sort (by {key}) gagal karena masalah tipe data: {e}")

        # Sequence-Bubble
        print(f"\n[5] Sequence-Bubble (by {key})...")
        try:
            start = time.time()
            sorted_data = sequence_bubble(transactions, key, search_targets[key])
            end = time.time()
            print(f"Hasil (5 data pertama): {[item[key] for item in sorted_data[:5]]}")
            print(f"Waktu Sequence-Bubble: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Sequence-Bubble (by {key}) gagal karena masalah tipe data: {e}")

        # Sequence-Selection
        print(f"\n[6] Sequence-Selection (by {key})...")
        try:
            start = time.time()
            sorted_data = sequence_selection(transactions, key, search_targets[key])
            end = time.time()
            print(f"Hasil (5 data pertama): {[item[key] for item in sorted_data[:5]]}")
            print(f"Waktu Sequence-Selection: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Sequence-Selection (by {key}) gagal karena masalah tipe data: {e}")

        # Binary-Bubble (hanya untuk kolom numerik)
        if key in ['ID_Numeric', 'Jumlah Pembelian']:
            print(f"\n[7] Binary-Bubble (by {key})...")
            try:
                start = time.time()
                sorted_data = binary_bubble(transactions, key, search_targets[key])
                end = time.time()
                print(f"Hasil (5 data pertama): {[item[key] for item in sorted_data[:5]]}")
                print(f"Waktu Binary-Bubble: {end - start:.6f} detik")
                print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
            except TypeError as e:
                print(f"⚠️ Binary-Bubble (by {key}) gagal karena masalah tipe data: {e}")
        else:
            print(f"\n[7] Binary-Bubble (by {key}) dilewati karena kolom bukan numerik")

        # Binary-Selection (hanya untuk kolom numerik)
        if key in ['ID_Numeric', 'Jumlah Pembelian']:
            print(f"\n[8] Binary-Selection (by {key})...")
            try:
                start = time.time()
                sorted_data = binary_selection(transactions, key, search_targets[key])
                end = time.time()
                print(f"Hasil (5 data pertama): {[item[key] for item in sorted_data[:5]]}")
                print(f"Waktu Binary-Selection: {end - start:.6f} detik")
                print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
            except TypeError as e:
                print(f"⚠️ Binary-Selection (by {key}) gagal karena masalah tipe data: {e}")
        else:
            print(f"\n[8] Binary-Selection (by {key}) dilewati karena kolom bukan numerik")

# %%
def normalize_columns(df, filename):
    # Column mappings berdasarkan kolom asli
    if filename == 'penjualan barang.csv':
        mapping = {
            'Unnamed: 0': 'ID',
            'nama.pembeli': 'Nama Pelanggan',
            'tanggal': 'Tanggal Pembelian',
            'nominal': 'Jumlah Pembelian'
        }
        df['Unnamed: 0'] = pd.to_numeric(df.get('Unnamed: 0', pd.Series()), errors='coerce').astype('Int64')
        df['nominal'] = pd.to_numeric(df.get('nominal', pd.Series()), errors='coerce')
    elif filename == 'data_transaksi.csv':
        mapping = {
            'id': 'ID',
            'nama': 'Nama Pelanggan',
            'tanggal': 'Tanggal Pembelian',
            'jumlah': 'Jumlah Pembelian'
        }
        df['id'] = df.get('id', pd.Series()).apply(extract_numeric_id)
        df['jumlah'] = pd.to_numeric(df.get('jumlah', pd.Series()), errors='coerce')
    elif filename == 'synthetic (1).csv':
        mapping = {
            'ID Pelanggan': 'ID',
            'Nama Pelanggan': 'Nama Pelanggan',
            'Waktu Pembelian': 'Tanggal Pembelian',
            'Jumlah Pembelian': 'Jumlah Pembelian'
        }
        df['ID Pelanggan'] = pd.to_numeric(df.get('ID Pelanggan', pd.Series()), errors='coerce').astype('Int64')
        df['Jumlah Pembelian'] = pd.to_numeric(df.get('Jumlah Pembelian', pd.Series()), errors='coerce')
    elif filename == 'Dataset Penjualan Buku.csv':
        mapping = {
            'ID': 'ID',
            'Nama_Pelanggan': 'Nama Pelanggan',
            'Tanggal_Pembelian': 'Tanggal Pembelian',
            'Jumlah_Pembelian': 'Jumlah Pembelian'
        }
        df['ID'] = df.get('ID', pd.Series()).apply(extract_numeric_id)
        df['Jumlah_Pembelian'] = pd.to_numeric(df.get('Jumlah_Pembelian', pd.Series()), errors='coerce')
    elif filename == 'dataset_tiruan.xlsx':
        mapping = {
            'ID': 'ID',
            'Nama Pelanggan': 'Nama Pelanggan',
            'Tanggal Pembelian': 'Tanggal Pembelian',
            'Jumlah Pembelian': 'Jumlah Pembelian'
        }
        df['ID'] = pd.to_numeric(df.get('ID', pd.Series()), errors='coerce').astype('Int64')
        df['Jumlah Pembelian'] = pd.to_numeric(df.get('Jumlah Pembelian', pd.Series()), errors='coerce')
    else:
        mapping = {}
        print(f"ℹ️ Tidak ada mapping kolom khusus untuk {filename}. Menggunakan kolom asli.")

    if mapping:
        valid_mapping = {k: v for k, v in mapping.items() if k in df.columns}
        if valid_mapping:
            df = df.rename(columns=valid_mapping)
        else:
            print(f"⚠️ Tidak ada kolom yang cocok dengan mapping untuk {filename}. Kolom yang ada: {list(df.columns)}")

    # Tambahkan kolom ID_Numeric
    if 'ID' in df.columns:
        df['ID_Numeric'] = df['ID'].apply(extract_numeric_id)
    return df

# %%
# MAIN
if __name__ == "__main__":
    print("Direktori kerja saat ini:", os.getcwd())
    print("File di direktori kerja:", os.listdir(os.getcwd()))
    drive_path = '/content/drive/MyDrive/DATASET'
    if os.path.exists(drive_path):
        print("File di /content/drive/MyDrive/DATASET:", os.listdir(drive_path))
    else:
        print("Folder /content/drive/MyDrive/DATASET tidak ditemukan")

    for filename, path in all_datasets.items():
        print(f"\n================== MEMUAT DATASET: {filename} ==================")
        try:
            # Periksa keberadaan file untuk path lokal
            if not path.startswith('http'):
                if not os.path.exists(path):
                    print(f"❌ File {filename} tidak ditemukan di: {path}")
                    print("Pastikan file ada di folder /content/drive/MyDrive/DATASET/")
                    continue

            # Baca dataset
            if path.endswith('.xlsx'):
                df = pd.read_excel(path)
            else:
                df = pd.read_csv(path)

            df.columns = [col.strip() for col in df.columns]
            print(f"Kolom asli: {list(df.columns)}")
            df = normalize_columns(df, filename)
            expected_columns = ['ID', 'Nama Pelanggan', 'Tanggal Pembelian', 'Jumlah Pembelian', 'ID_Numeric']

            # Pilih kolom yang diperlukan, hindari duplikasi
            available_columns = [col for col in expected_columns if col in df.columns]
            if len(available_columns) < 4:  # Minimal harus ada ID, Nama Pelanggan, Tanggal Pembelian, Jumlah Pembelian
                print(f"❌ Dataset {filename} tidak memiliki kolom yang cukup. Kolom yang hilang: {[col for col in expected_columns if col not in df.columns]}")
                print(f"Kolom yang ada: {list(df.columns)}")
                continue
            df = df[available_columns].copy()

            # Konversi tipe data
            df['ID_Numeric'] = pd.to_numeric(df['ID_Numeric'], errors='coerce').astype('Int64')
            df['Jumlah Pembelian'] = pd.to_numeric(df['Jumlah Pembelian'], errors='coerce')
            if filename == 'data_transaksi.csv':
                df['Tanggal Pembelian'] = pd.to_datetime(df['Tanggal Pembelian'], format='%Y-%m-%d', errors='coerce').dt.strftime('%d/%m/%Y')
            else:
                df['Tanggal Pembelian'] = pd.to_datetime(df['Tanggal Pembelian'], errors='coerce').dt.strftime('%d/%m/%Y')

            # Log baris dengan nilai kosong
            missing_rows = df[df[available_columns].isna().any(axis=1)]
            if not missing_rows.empty:
                print(f"⚠️ {len(missing_rows)} baris dengan nilai kosong di kolom kunci: {missing_rows.head().to_dict(orient='records')}")

            # Hapus baris dengan nilai kosong
            df = df.dropna(subset=available_columns)

            transaksi_data = df.to_dict(orient='records')
            print(f"✅ Jumlah Data: {len(transaksi_data)}")
            print("Contoh Data (5 data pertama):")
            for txn in transaksi_data[:5]:
                print(txn)

            if transaksi_data:
                benchmark(transaksi_data)
            else:
                print(f"⚠️ Tidak ada data transaksi yang valid di {filename} setelah pemrosesan. Melewati benchmark.")
        except FileNotFoundError:
            print(f"❌ Gagal memproses dataset {filename}: File tidak ditemukan di lokasi: {path}")
        except Exception as e:
            print(f"❌ Gagal memproses dataset {filename}: {e}")
# Out:
# Direktori kerja saat ini: /content
# File di direktori kerja: ['.config', 'drive', 'sample_data']
# File di /content/drive/MyDrive/DATASET: ['Dataset Penjualan Buku.csv', 'dataset_tiruan.xlsx', 'synthetic (1).csv', 'olist_products_dataset.csv', 'olist_orders_dataset.csv']
#
# ================== MEMUAT DATASET: penjualan barang.csv ==================
# Kolom asli: ['Unnamed: 0', 'tanggal', 'nama.pembeli', 'nama.barang', 'kuantum', 'nominal']
# ✅ Jumlah Data: 1289
# Contoh Data (5 data pertama):
# {'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}
# {'ID': 2, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 8400000.0, 'ID_Numeric': 2}
# {'ID': 3, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 62910000.0, 'ID_Numeric': 3}
# {'ID': 4, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 4855200.0, 'ID_Numeric': 4}
# {'ID': 5, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 1162000.0, 'ID_Numeric': 5}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID_Numeric ---
#
# [1] Sequence Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000002 detik
# Ruang Memori: 11288 bytes
#
# [2] Binary Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000006 detik
# Ruang Memori: 10376 bytes
#
# [3] Bubble Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Bubble Sort: 0.000219 detik
# Ruang Memori: 10368 bytes
#
# [4] Selection Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Selection Sort: 0.124351 detik
# Ruang Memori: 10368 bytes
#
# [5] Sequence-Bubble (by ID_Numeric)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Sequence-Bubble: 0.000263 detik
# Ruang Memori: 10368 bytes
#
# [6] Sequence-Selection (by ID_Numeric)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Sequence-Selection: 0.125359 detik
# Ruang Memori: 10368 bytes
#
# [7] Binary-Bubble (by ID_Numeric)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Binary-Bubble: 0.000430 detik
# Ruang Memori: 10368 bytes
#
# [8] Binary-Selection (by ID_Numeric)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Binary-Selection: 0.119279 detik
# Ruang Memori: 10368 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Sequence Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Sequence Search: 0.000118 detik
# Ruang Memori: 11288 bytes
#
# [2] Binary Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Binary Search: 0.000004 detik
# Ruang Memori: 10376 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [46000.0, 69000.0, 92000.0, 92000.0, 92000.0]
# Waktu Bubble Sort: 0.188086 detik
# Ruang Memori: 10368 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [46000.0, 69000.0, 92000.0, 92000.0, 92000.0]
# Waktu Selection Sort: 0.147291 detik
# Ruang Memori: 10368 bytes
#
# [5] Sequence-Bubble (by Jumlah Pembelian)...
# Sequence Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): [46000.0, 69000.0, 92000.0, 92000.0, 92000.0]
# Waktu Sequence-Bubble: 0.183687 detik
# Ruang Memori: 10368 bytes
#
# [6] Sequence-Selection (by Jumlah Pembelian)...
# Sequence Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): [46000.0, 69000.0, 92000.0, 92000.0, 92000.0]
# Waktu Sequence-Selection: 0.135959 detik
# Ruang Memori: 10368 bytes
#
# [7] Binary-Bubble (by Jumlah Pembelian)...
# Binary Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): [46000.0, 69000.0, 92000.0, 92000.0, 92000.0]
# Waktu Binary-Bubble: 0.183140 detik
# Ruang Memori: 10368 bytes
#
# [8] Binary-Selection (by Jumlah Pembelian)...
# Binary Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): [46000.0, 69000.0, 92000.0, 92000.0, 92000.0]
# Waktu Binary-Selection: 0.136464 detik
# Ruang Memori: 10368 bytes
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Sequence Search (by Nama Pelanggan)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000005 detik
# Ruang Memori: 11288 bytes
#
# [2] Binary Search (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA']
# Waktu Bubble Sort: 0.186361 detik
# Ruang Memori: 10368 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA']
# Waktu Selection Sort: 0.160500 detik
# Ruang Memori: 10368 bytes
#
# [5] Sequence-Bubble (by Nama Pelanggan)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA']
# Waktu Sequence-Bubble: 0.186821 detik
# Ruang Memori: 10368 bytes
#
# [6] Sequence-Selection (by Nama Pelanggan)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA']
# Waktu Sequence-Selection: 0.139341 detik
# Ruang Memori: 10368 bytes
#
# [7] Binary-Bubble (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# [8] Binary-Selection (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Sequence Search (by Tanggal Pembelian)...
# Hasil: []
# Waktu Sequence Search: 0.000143 detik
# Ruang Memori: 11288 bytes
#
# [2] Binary Search (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021']
# Waktu Bubble Sort: 0.182685 detik
# Ruang Memori: 10368 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021']
# Waktu Selection Sort: 0.141725 detik
# Ruang Memori: 10368 bytes
#
# [5] Sequence-Bubble (by Tanggal Pembelian)...
# Sequence Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): ['01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021']
# Waktu Sequence-Bubble: 0.189573 detik
# Ruang Memori: 10368 bytes
#
# [6] Sequence-Selection (by Tanggal Pembelian)...
# Sequence Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): ['01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021']
# Waktu Sequence-Selection: 0.145194 detik
# Ruang Memori: 10368 bytes
#
# [7] Binary-Bubble (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# [8] Binary-Selection (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# ================== MEMUAT DATASET: data_transaksi.csv ==================
# Kolom asli: ['id', 'nama', 'tanggal', 'jumlah']
# ✅ Jumlah Data: 10000
# Contoh Data (5 data pertama):
# {'ID': 0, 'Nama Pelanggan': 'OMODF', 'Tanggal Pembelian': '28/10/2024', 'Jumlah Pembelian': 839.53, 'ID_Numeric': 0}
# {'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}
# {'ID': 2, 'Nama Pelanggan': 'MJHYJ', 'Tanggal Pembelian': '29/07/2024', 'Jumlah Pembelian': 103.66, 'ID_Numeric': 2}
# {'ID': 3, 'Nama Pelanggan': 'XTQTS', 'Tanggal Pembelian': '02/12/2025', 'Jumlah Pembelian': 191.2, 'ID_Numeric': 3}
# {'ID': 4, 'Nama Pelanggan': 'SFLLP', 'Tanggal Pembelian': '26/03/2025', 'Jumlah Pembelian': 143.33, 'ID_Numeric': 4}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID_Numeric ---
#
# [1] Sequence Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000003 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000006 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by ID_Numeric)...
# Hasil (5 data pertama): [0, 1, 2, 3, 4]
# Waktu Bubble Sort: 0.001740 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by ID_Numeric)...
# Hasil (5 data pertama): [0, 1, 2, 3, 4]
# Waktu Selection Sort: 9.003764 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by ID_Numeric)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [0, 1, 2, 3, 4]
# Waktu Sequence-Bubble: 0.001920 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by ID_Numeric)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [0, 1, 2, 3, 4]
# Waktu Sequence-Selection: 8.945885 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by ID_Numeric)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [0, 1, 2, 3, 4]
# Waktu Binary-Bubble: 0.002865 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by ID_Numeric)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [0, 1, 2, 3, 4]
# Waktu Binary-Selection: 7.470862 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Sequence Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Sequence Search: 0.000794 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Binary Search: 0.000009 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [10.04, 10.08, 10.14, 10.22, 10.31]
# Waktu Bubble Sort: 15.650491 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [10.04, 10.08, 10.14, 10.22, 10.31]
# Waktu Selection Sort: 10.854053 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Jumlah Pembelian)...
# Sequence Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): [10.04, 10.08, 10.14, 10.22, 10.31]
# Waktu Sequence-Bubble: 15.339466 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Jumlah Pembelian)...
# Sequence Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): [10.04, 10.08, 10.14, 10.22, 10.31]
# Waktu Sequence-Selection: 10.993011 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Jumlah Pembelian)...
# Binary Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): [10.04, 10.08, 10.14, 10.22, 10.31]
# Waktu Binary-Bubble: 15.159819 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by Jumlah Pembelian)...
# Binary Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): [10.04, 10.08, 10.14, 10.22, 10.31]
# Waktu Binary-Selection: 11.095666 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Sequence Search (by Nama Pelanggan)...
# Hasil: []
# Waktu Sequence Search: 0.000817 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['AACCL', 'AACFT', 'AAFDL', 'AAFNP', 'AAMIK']
# Waktu Bubble Sort: 14.927915 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['AACCL', 'AACFT', 'AAFDL', 'AAFNP', 'AAMIK']
# Waktu Selection Sort: 11.327883 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Nama Pelanggan)...
# Sequence Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): ['AACCL', 'AACFT', 'AAFDL', 'AAFNP', 'AAMIK']
# Waktu Sequence-Bubble: 14.900715 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Nama Pelanggan)...
# Sequence Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): ['AACCL', 'AACFT', 'AAFDL', 'AAFNP', 'AAMIK']
# Waktu Sequence-Selection: 11.326811 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# [8] Binary-Selection (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Sequence Search (by Tanggal Pembelian)...
# Hasil: []
# Waktu Sequence Search: 0.001014 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023']
# Waktu Bubble Sort: 15.955288 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023']
# Waktu Selection Sort: 11.310089 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Tanggal Pembelian)...
# Sequence Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): ['01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023']
# Waktu Sequence-Bubble: 16.806619 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Tanggal Pembelian)...
# Sequence Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): ['01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023']
# Waktu Sequence-Selection: 10.452487 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# [8] Binary-Selection (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# ================== MEMUAT DATASET: synthetic (1).csv ==================
# Kolom asli: ['ID Pelanggan', 'Nama Pelanggan', 'Waktu Pembelian', 'Jumlah Pembelian']
# ✅ Jumlah Data: 10000
# Contoh Data (5 data pertama):
# {'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}
# {'ID': 2, 'Nama Pelanggan': 'Kirana Susanti', 'Tanggal Pembelian': '28/09/2024', 'Jumlah Pembelian': 21199, 'ID_Numeric': 2}
# {'ID': 3, 'Nama Pelanggan': 'Gita Bayhaqie', 'Tanggal Pembelian': '19/07/2024', 'Jumlah Pembelian': 39819, 'ID_Numeric': 3}
# {'ID': 4, 'Nama Pelanggan': 'Aditya Wulandari', 'Tanggal Pembelian': '14/03/2024', 'Jumlah Pembelian': 485896, 'ID_Numeric': 4}
# {'ID': 5, 'Nama Pelanggan': 'Omar Sulistyo', 'Tanggal Pembelian': '22/07/2024', 'Jumlah Pembelian': 72706, 'ID_Numeric': 5}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID_Numeric ---
#
# [1] Sequence Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000005 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000015 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Bubble Sort: 0.005996 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Selection Sort: 8.976935 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by ID_Numeric)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Sequence-Bubble: 0.002019 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by ID_Numeric)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Sequence-Selection: 9.051611 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by ID_Numeric)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Binary-Bubble: 0.003204 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by ID_Numeric)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Binary-Selection: 7.479509 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Sequence Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Sequence Search: 0.001052 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Binary Search: 0.000008 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [10001, 10022, 10131, 10164, 10247]
# Waktu Bubble Sort: 16.153283 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [10001, 10022, 10131, 10164, 10247]
# Waktu Selection Sort: 10.760350 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Jumlah Pembelian)...
# Sequence Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): [10001, 10022, 10131, 10164, 10247]
# Waktu Sequence-Bubble: 16.599927 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Jumlah Pembelian)...
# Sequence Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): [10001, 10022, 10131, 10164, 10247]
# Waktu Sequence-Selection: 9.743482 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Jumlah Pembelian)...
# Binary Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): [10001, 10022, 10131, 10164, 10247]
# Waktu Binary-Bubble: 16.691998 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by Jumlah Pembelian)...
# Binary Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): [10001, 10022, 10131, 10164, 10247]
# Waktu Binary-Selection: 10.007173 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Sequence Search (by Nama Pelanggan)...
# Hasil: []
# Waktu Sequence Search: 0.001816 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['Abdi Adinata', 'Abdi Aji', 'Abdi Almira', 'Abdi Almira', 'Abdi Almira']
# Waktu Bubble Sort: 16.165961 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['Abdi Adinata', 'Abdi Aji', 'Abdi Almira', 'Abdi Almira', 'Abdi Almira']
# Waktu Selection Sort: 10.006917 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Nama Pelanggan)...
# Sequence Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): ['Abdi Adinata', 'Abdi Aji', 'Abdi Almira', 'Abdi Almira', 'Abdi Almira']
# Waktu Sequence-Bubble: 16.138679 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Nama Pelanggan)...
# Sequence Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): ['Abdi Adinata', 'Abdi Aji', 'Abdi Almira', 'Abdi Almira', 'Abdi Almira']
# Waktu Sequence-Selection: 9.746384 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# [8] Binary-Selection (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Sequence Search (by Tanggal Pembelian)...
# Hasil: []
# Waktu Sequence Search: 0.001608 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024']
# Waktu Bubble Sort: 16.717857 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024']
# Waktu Selection Sort: 10.110123 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Tanggal Pembelian)...
# Sequence Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): ['01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024']
# Waktu Sequence-Bubble: 16.594006 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Tanggal Pembelian)...
# Sequence Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): ['01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024']
# Waktu Sequence-Selection: 10.591315 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# [8] Binary-Selection (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# ================== MEMUAT DATASET: Dataset Penjualan Buku.csv ==================
# Kolom asli: ['ID', 'Nama_Pelanggan', 'Tanggal_Pembelian', 'Jumlah_Pembelian', 'Kategori_Buku', 'Harga_Satuan', 'Total_Harga']
# ✅ Jumlah Data: 10000
# Contoh Data (5 data pertama):
# {'ID': 1944, 'Nama Pelanggan': 'Balidin Dongoran, S.T.', 'Tanggal Pembelian': '30/08/2024', 'Jumlah Pembelian': 7, 'ID_Numeric': 1944}
# {'ID': 2455, 'Nama Pelanggan': 'Darmana Mandala', 'Tanggal Pembelian': '05/12/2024', 'Jumlah Pembelian': 20, 'ID_Numeric': 2455}
# {'ID': 3512, 'Nama Pelanggan': 'Ciaobella Wastuti, M.Pd', 'Tanggal Pembelian': '14/08/2024', 'Jumlah Pembelian': 15, 'ID_Numeric': 3512}
# {'ID': 3354, 'Nama Pelanggan': 'Lantar Anggraini', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 11, 'ID_Numeric': 3354}
# {'ID': 2721, 'Nama Pelanggan': 'Among Iswahyudi', 'Tanggal Pembelian': '04/07/2024', 'Jumlah Pembelian': 8, 'ID_Numeric': 2721}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID_Numeric ---
#
# [1] Sequence Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000597 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000011 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Bubble Sort: 14.322821 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Selection Sort: 8.798279 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by ID_Numeric)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Sequence-Bubble: 13.772489 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by ID_Numeric)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Sequence-Selection: 10.177970 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by ID_Numeric)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Binary-Bubble: 13.685168 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by ID_Numeric)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Binary-Selection: 9.953289 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Sequence Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Sequence Search: 0.000994 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Jumlah Pembelian)...
# Hasil: []
# Waktu Binary Search: 0.000009 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Bubble Sort: 13.708183 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Selection Sort: 10.155035 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Jumlah Pembelian)...
# Sequence Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Sequence-Bubble: 13.605433 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Jumlah Pembelian)...
# Sequence Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Sequence-Selection: 9.122041 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Jumlah Pembelian)...
# Binary Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Binary-Bubble: 14.500682 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by Jumlah Pembelian)...
# Binary Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Binary-Selection: 9.113344 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Sequence Search (by Nama Pelanggan)...
# Hasil: []
# Waktu Sequence Search: 0.000882 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['Abyasa Firgantoro, S.Sos', 'Abyasa Habibi', 'Abyasa Lazuardi', 'Abyasa Prasetyo', 'Abyasa Purwanti']
# Waktu Bubble Sort: 15.078810 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['Abyasa Firgantoro, S.Sos', 'Abyasa Habibi', 'Abyasa Lazuardi', 'Abyasa Prasetyo', 'Abyasa Purwanti']
# Waktu Selection Sort: 11.268759 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Nama Pelanggan)...
# Sequence Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): ['Abyasa Firgantoro, S.Sos', 'Abyasa Habibi', 'Abyasa Lazuardi', 'Abyasa Prasetyo', 'Abyasa Purwanti']
# Waktu Sequence-Bubble: 15.195842 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Nama Pelanggan)...
# Sequence Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): ['Abyasa Firgantoro, S.Sos', 'Abyasa Habibi', 'Abyasa Lazuardi', 'Abyasa Prasetyo', 'Abyasa Purwanti']
# Waktu Sequence-Selection: 11.254239 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# [8] Binary-Selection (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Sequence Search (by Tanggal Pembelian)...
# Hasil: []
# Waktu Sequence Search: 0.001069 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025']
# Waktu Bubble Sort: 16.126168 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025']
# Waktu Selection Sort: 11.045369 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Tanggal Pembelian)...
# Sequence Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): ['01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025']
# Waktu Sequence-Bubble: 16.857408 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Tanggal Pembelian)...
# Sequence Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): ['01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025']
# Waktu Sequence-Selection: 10.419501 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# [8] Binary-Selection (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# ================== MEMUAT DATASET: dataset_tiruan.xlsx ==================
# Kolom asli: ['ID', 'Nama Pelanggan', 'Tanggal Pembelian', 'Jumlah Pembelian']
# ⚠️ 6073 baris dengan nilai kosong di kolom kunci: [{'ID': 2, 'Nama Pelanggan': 'Gregory Rodriguez', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 892, 'ID_Numeric': 2}, {'ID': 4, 'Nama Pelanggan': 'Jordan Williams', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 725, 'ID_Numeric': 4}, {'ID': 7, 'Nama Pelanggan': 'Susan Sampson', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 358, 'ID_Numeric': 7}, {'ID': 8, 'Nama Pelanggan': 'Jessica Williams', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 49, 'ID_Numeric': 8}, {'ID': 9, 'Nama Pelanggan': 'Colleen Johnson', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 784, 'ID_Numeric': 9}]
# ✅ Jumlah Data: 3927
# Contoh Data (5 data pertama):
# {'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}
# {'ID': 3, 'Nama Pelanggan': 'Jessica Allen', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 983, 'ID_Numeric': 3}
# {'ID': 5, 'Nama Pelanggan': 'Jordan Brown', 'Tanggal Pembelian': '02/01/2022', 'Jumlah Pembelian': 847, 'ID_Numeric': 5}
# {'ID': 6, 'Nama Pelanggan': 'Jordan Sampson', 'Tanggal Pembelian': '12/03/2022', 'Jumlah Pembelian': 715, 'ID_Numeric': 6}
# {'ID': 10, 'Nama Pelanggan': 'Susan Sampson', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 377, 'ID_Numeric': 10}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID_Numeric ---
#
# [1] Sequence Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000003 detik
# Ruang Memori: 33048 bytes
#
# [2] Binary Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000009 detik
# Ruang Memori: 31480 bytes
#
# [3] Bubble Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 3, 5, 6, 10]
# Waktu Bubble Sort: 0.001485 detik
# Ruang Memori: 31472 bytes
#
# [4] Selection Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 3, 5, 6, 10]
# Waktu Selection Sort: 2.024272 detik
# Ruang Memori: 31472 bytes
#
# [5] Sequence-Bubble (by ID_Numeric)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 3, 5, 6, 10]
# Waktu Sequence-Bubble: 0.000863 detik
# Ruang Memori: 31472 bytes
#
# [6] Sequence-Selection (by ID_Numeric)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 3, 5, 6, 10]
# Waktu Sequence-Selection: 1.152061 detik
# Ruang Memori: 31472 bytes
#
# [7] Binary-Bubble (by ID_Numeric)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 3, 5, 6, 10]
# Waktu Binary-Bubble: 0.001239 detik
# Ruang Memori: 31472 bytes
#
# [8] Binary-Selection (by ID_Numeric)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 3, 5, 6, 10]
# Waktu Binary-Selection: 1.150012 detik
# Ruang Memori: 31472 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Sequence Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 1999, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '12/01/2022', 'Jumlah Pembelian': 1000, 'ID_Numeric': 1999}]
# Waktu Sequence Search: 0.000170 detik
# Ruang Memori: 33048 bytes
#
# [2] Binary Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 1999, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '12/01/2022', 'Jumlah Pembelian': 1000, 'ID_Numeric': 1999}]
# Waktu Binary Search: 0.000008 detik
# Ruang Memori: 31480 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Bubble Sort: 1.871134 detik
# Ruang Memori: 31472 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Selection Sort: 1.331848 detik
# Ruang Memori: 31472 bytes
#
# [5] Sequence-Bubble (by Jumlah Pembelian)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1999, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '12/01/2022', 'Jumlah Pembelian': 1000, 'ID_Numeric': 1999}]
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Sequence-Bubble: 1.860852 detik
# Ruang Memori: 31472 bytes
#
# [6] Sequence-Selection (by Jumlah Pembelian)...
# Sequence Search sebelum Selection Sort: [{'ID': 1999, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '12/01/2022', 'Jumlah Pembelian': 1000, 'ID_Numeric': 1999}]
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Sequence-Selection: 1.339652 detik
# Ruang Memori: 31472 bytes
#
# [7] Binary-Bubble (by Jumlah Pembelian)...
# Binary Search sebelum Bubble Sort: [{'ID': 1999, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '12/01/2022', 'Jumlah Pembelian': 1000, 'ID_Numeric': 1999}]
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Binary-Bubble: 2.601051 detik
# Ruang Memori: 31472 bytes
#
# [8] Binary-Selection (by Jumlah Pembelian)...
# Binary Search sebelum Selection Sort: [{'ID': 1999, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '12/01/2022', 'Jumlah Pembelian': 1000, 'ID_Numeric': 1999}]
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Binary-Selection: 2.123364 detik
# Ruang Memori: 31472 bytes
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Sequence Search (by Nama Pelanggan)...
# Hasil: []
# Waktu Sequence Search: 0.000403 detik
# Ruang Memori: 33048 bytes
#
# [2] Binary Search (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen']
# Waktu Bubble Sort: 1.830400 detik
# Ruang Memori: 31472 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen']
# Waktu Selection Sort: 1.334236 detik
# Ruang Memori: 31472 bytes
#
# [5] Sequence-Bubble (by Nama Pelanggan)...
# Sequence Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): ['Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen']
# Waktu Sequence-Bubble: 1.832629 detik
# Ruang Memori: 31472 bytes
#
# [6] Sequence-Selection (by Nama Pelanggan)...
# Sequence Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): ['Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen']
# Waktu Sequence-Selection: 1.328207 detik
# Ruang Memori: 31472 bytes
#
# [7] Binary-Bubble (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# [8] Binary-Selection (by Nama Pelanggan) dilewati karena kolom bukan numerik
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Sequence Search (by Tanggal Pembelian)...
# Hasil: []
# Waktu Sequence Search: 0.000458 detik
# Ruang Memori: 33048 bytes
#
# [2] Binary Search (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022']
# Waktu Bubble Sort: 1.959019 detik
# Ruang Memori: 31472 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022']
# Waktu Selection Sort: 1.558940 detik
# Ruang Memori: 31472 bytes
#
# [5] Sequence-Bubble (by Tanggal Pembelian)...
# Sequence Search sebelum Bubble Sort: Tidak ditemukan
# Hasil (5 data pertama): ['01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022']
# Waktu Sequence-Bubble: 3.377695 detik
# Ruang Memori: 31472 bytes
#
# [6] Sequence-Selection (by Tanggal Pembelian)...
# Sequence Search sebelum Selection Sort: Tidak ditemukan
# Hasil (5 data pertama): ['01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022']
# Waktu Sequence-Selection: 1.396544 detik
# Ruang Memori: 31472 bytes
#
# [7] Binary-Bubble (by Tanggal Pembelian) dilewati karena kolom bukan numerik
#
# [8] Binary-Selection (by Tanggal Pembelian) dilewati karena kolom bukan numerik

# %%
import time
import pandas as pd
import sys
import os
from google.colab import drive
from IPython.display import display

# Mount Google Drive
drive.mount('/content/drive')

# Dataset paths
github_datasets = {
    'penjualan barang.csv': 'https://raw.githubusercontent.com/Anggunsky/datasetPenjualan/main/penjualan%20barang.csv',
    'data_transaksi.csv': 'https://raw.githubusercontent.com/annisareida/Benchmarking-Algoritma/main/data_transaksi.csv',
}
drive_datasets = {
    'synthetic (1).csv': '/content/drive/MyDrive/DATASET/synthetic (1).csv',
    'Dataset Penjualan Buku.csv': '/content/drive/MyDrive/DATASET/Dataset Penjualan Buku.csv',
    'dataset_tiruan.xlsx': '/content/drive/MyDrive/DATASET/dataset_tiruan.xlsx',
}
all_datasets = {**github_datasets, **drive_datasets}

# FUNCTION UTILITIES
def extract_numeric_id(id_str):
    try:
        if isinstance(id_str, str) and id_str.startswith('TRX'):
            return int(id_str.replace('TRX', ''))
        return int(id_str)  # Untuk ID numerik langsung
    except:
        return -1  # Tangani ID tidak valid

def sequence_search(data, key, target):
    for i, item in enumerate(data):
        if item.get(key) == target:
            return [item]  # Return as list for consistency
    return []

def binary_search(data, key, target):
    left, right = 0, len(data) - 1
    while left <= right:
        mid = (left + right) // 2
        current = data[mid].get(key)
        if current == target:
            return [data[mid]]  # Return as list for consistency
        elif current < target:  # Perbandingan mendukung string dan numerik
            left = mid + 1
        else:
            right = mid - 1
    return []

def bubble_sort(data, key):
    data_copy = data[:]
    n = len(data_copy)
    for i in range(n):
        swapped = False
        for j in range(0, n - i - 1):
            if (data_copy[j].get(key) is not None and
                data_copy[j + 1].get(key) is not None and
                data_copy[j][key] > data_copy[j + 1][key]):
                data_copy[j], data_copy[j + 1] = data_copy[j + 1], data_copy[j]
                swapped = True
        if not swapped:
            break
    return data_copy

def selection_sort(data, key):
    data_copy = data[:]
    n = len(data_copy)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if (data_copy[j].get(key) is not None and
                data_copy[min_idx].get(key) is not None and
                data_copy[j][key] < data_copy[min_idx][key]):
                min_idx = j
        data_copy[i], data_copy[min_idx] = data_copy[min_idx], data_copy[i]
    return data_copy

def sequence_bubble(data, key, target):
    search_result = sequence_search(data, key, target)
    print(f"Sequence Search sebelum Bubble Sort: {search_result[:5] if search_result else 'Tidak ditemukan'}")
    return bubble_sort(data, key)

def sequence_selection(data, key, target):
    search_result = sequence_search(data, key, target)
    print(f"Sequence Search sebelum Selection Sort: {search_result[:5] if search_result else 'Tidak ditemukan'}")
    return selection_sort(data, key)

def binary_bubble(data, key, target):
    sorted_data = sorted(data, key=lambda x: x.get(key, '') if isinstance(x.get(key), str) else x.get(key, 0))
    search_result = binary_search(sorted_data, key, target)
    print(f"Binary Search sebelum Bubble Sort: {search_result[:5] if search_result else 'Tidak ditemukan'}")
    return bubble_sort(data, key)

def binary_selection(data, key, target):
    sorted_data = sorted(data, key=lambda x: x.get(key, '') if isinstance(x.get(key), str) else x.get(key, 0))
    search_result = binary_search(sorted_data, key, target)
    print(f"Binary Search sebelum Selection Sort: {search_result[:5] if search_result else 'Tidak ditemukan'}")
    return selection_sort(data, key)

def memory_complexity(data):
    return sys.getsizeof(data)

# BENCHMARKING FUNCTION
def benchmark(transactions, dataset_name):
    print("\n==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================")

    keys = ['ID_Numeric', 'Jumlah Pembelian', 'Nama Pelanggan', 'Tanggal Pembelian']
    # Target pencarian disesuaikan per dataset
    search_targets = {
        'penjualan barang.csv': {
            'ID_Numeric': 1,
            'Jumlah Pembelian': 9840000.0,  # Dari data
            'Nama Pelanggan': 'TOKO HERUNIAWATI',
            'Tanggal Pembelian': '02/01/2020'
        },
        'data_transaksi.csv': {
            'ID_Numeric': 1,
            'Jumlah Pembelian': 809.47,  # Dari data
            'Nama Pelanggan': 'QDFKU',
            'Tanggal Pembelian': '04/07/2023'
        },
        'synthetic (1).csv': {
            'ID_Numeric': 1,
            'Jumlah Pembelian': 275031,  # Dari data
            'Nama Pelanggan': 'Udin Sari',
            'Tanggal Pembelian': '29/06/2024'
        },
        'Dataset Penjualan Buku.csv': {
            'ID_Numeric': 1,
            'Jumlah Pembelian': 6,  # Dari data
            'Nama Pelanggan': 'Tira Palastri, S.Kom',
            'Tanggal Pembelian': '14/04/2025'
        },
        'dataset_tiruan.xlsx': {
            'ID_Numeric': 1,
            'Jumlah Pembelian': 880,  # Dari data
            'Nama Pelanggan': 'Michael Bishop',
            'Tanggal Pembelian': '08/09/2022'
        }
    }

    for key in keys:
        print(f"\n--- Benchmarking untuk Kolom: {key} ---")
        target = search_targets[dataset_name][key]

        # Sequence Search
        print(f"\n[1] Sequence Search (by {key})...")
        start = time.time()
        result = sequence_search(transactions, key, target)
        end = time.time()
        print(f"Hasil: {result[:5]}" if len(result) > 5 else f"Hasil: {result}")
        print(f"Waktu Sequence Search: {end - start:.6f} detik")
        print(f"Ruang Memori: {memory_complexity(transactions)} bytes")

        # Binary Search
        print(f"\n[2] Binary Search (by {key})...")
        try:
            sorted_txn = sorted(transactions, key=lambda x: x.get(key, '') if isinstance(x.get(key), str) else x.get(key, 0))
            start = time.time()
            result = binary_search(sorted_txn, key, target)
            end = time.time()
            print(f"Hasil: {result[:5]}" if len(result) > 5 else f"Hasil: {result}")
            print(f"Waktu Binary Search: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_txn)} bytes")
        except TypeError as e:
            print(f"⚠️ Binary Search (by {key}) gagal karena masalah tipe data: {e}")

        # Bubble Sort
        print(f"\n[3] Bubble Sort (by {key})...")
        try:
            start = time.time()
            sorted_data = bubble_sort(transactions, key)
            end = time.time()
            print(f"Hasil (5 data pertama): {[item[key] for item in sorted_data[:5]]}")
            print(f"Waktu Bubble Sort: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Bubble Sort (by {key}) gagal karena masalah tipe data: {e}")

        # Selection Sort
        print(f"\n[4] Selection Sort (by {key})...")
        try:
            start = time.time()
            sorted_data = selection_sort(transactions, key)
            end = time.time()
            print(f"Hasil (5 data pertama): {[item[key] for item in sorted_data[:5]]}")
            print(f"Waktu Selection Sort: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Selection Sort (by {key}) gagal karena masalah tipe data: {e}")

        # Sequence-Bubble
        print(f"\n[5] Sequence-Bubble (by {key})...")
        try:
            start = time.time()
            sorted_data = sequence_bubble(transactions, key, target)
            end = time.time()
            print(f"Hasil (5 data pertama): {[item[key] for item in sorted_data[:5]]}")
            print(f"Waktu Sequence-Bubble: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Sequence-Bubble (by {key}) gagal karena masalah tipe data: {e}")

        # Sequence-Selection
        print(f"\n[6] Sequence-Selection (by {key})...")
        try:
            start = time.time()
            sorted_data = sequence_selection(transactions, key, target)
            end = time.time()
            print(f"Hasil (5 data pertama): {[item[key] for item in sorted_data[:5]]}")
            print(f"Waktu Sequence-Selection: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Sequence-Selection (by {key}) gagal karena masalah tipe data: {e}")

        # Binary-Bubble
        print(f"\n[7] Binary-Bubble (by {key})...")
        try:
            start = time.time()
            sorted_data = binary_bubble(transactions, key, target)
            end = time.time()
            print(f"Hasil (5 data pertama): {[item[key] for item in sorted_data[:5]]}")
            print(f"Waktu Binary-Bubble: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Binary-Bubble (by {key}) gagal karena masalah tipe data: {e}")

        # Binary-Selection
        print(f"\n[8] Binary-Selection (by {key})...")
        try:
            start = time.time()
            sorted_data = binary_selection(transactions, key, target)
            end = time.time()
            print(f"Hasil (5 data pertama): {[item[key] for item in sorted_data[:5]]}")
            print(f"Waktu Binary-Selection: {end - start:.6f} detik")
            print(f"Ruang Memori: {memory_complexity(sorted_data)} bytes")
        except TypeError as e:
            print(f"⚠️ Binary-Selection (by {key}) gagal karena masalah tipe data: {e}")

def normalize_columns(df, filename):
    if filename == 'penjualan barang.csv':
        mapping = {
            'Unnamed: 0': 'ID',
            'nama.pembeli': 'Nama Pelanggan',
            'tanggal': 'Tanggal Pembelian',
            'nominal': 'Jumlah Pembelian'
        }
        df['Unnamed: 0'] = pd.to_numeric(df.get('Unnamed: 0', pd.Series()), errors='coerce').astype('Int64')
        df['nominal'] = pd.to_numeric(df.get('nominal', pd.Series()), errors='coerce')
    elif filename == 'data_transaksi.csv':
        mapping = {
            'id': 'ID',
            'nama': 'Nama Pelanggan',
            'tanggal': 'Tanggal Pembelian',
            'jumlah': 'Jumlah Pembelian'
        }
        df['id'] = df.get('id', pd.Series()).apply(extract_numeric_id)
        df['jumlah'] = pd.to_numeric(df.get('jumlah', pd.Series()), errors='coerce')
    elif filename == 'synthetic (1).csv':
        mapping = {
            'ID Pelanggan': 'ID',
            'Nama Pelanggan': 'Nama Pelanggan',
            'Waktu Pembelian': 'Tanggal Pembelian',
            'Jumlah Pembelian': 'Jumlah Pembelian'
        }
        df['ID Pelanggan'] = pd.to_numeric(df.get('ID Pelanggan', pd.Series()), errors='coerce').astype('Int64')
        df['Jumlah Pembelian'] = pd.to_numeric(df.get('Jumlah Pembelian', pd.Series()), errors='coerce')
    elif filename == 'Dataset Penjualan Buku.csv':
        mapping = {
            'ID': 'ID',
            'Nama_Pelanggan': 'Nama Pelanggan',
            'Tanggal_Pembelian': 'Tanggal Pembelian',
            'Jumlah_Pembelian': 'Jumlah Pembelian'
        }
        df['ID'] = df.get('ID', pd.Series()).apply(extract_numeric_id)
        df['Jumlah_Pembelian'] = pd.to_numeric(df.get('Jumlah_Pembelian', pd.Series()), errors='coerce')
    elif filename == 'dataset_tiruan.xlsx':
        mapping = {
            'ID': 'ID',
            'Nama Pelanggan': 'Nama Pelanggan',
            'Tanggal Pembelian': 'Tanggal Pembelian',
            'Jumlah Pembelian': 'Jumlah Pembelian'
        }
        df['ID'] = pd.to_numeric(df.get('ID', pd.Series()), errors='coerce').astype('Int64')
        df['Jumlah Pembelian'] = pd.to_numeric(df.get('Jumlah Pembelian', pd.Series()), errors='coerce')
    else:
        mapping = {}
        print(f"ℹ️ Tidak ada mapping kolom khusus untuk {filename}. Menggunakan kolom asli.")

    if mapping:
        valid_mapping = {k: v for k, v in mapping.items() if k in df.columns}
        if valid_mapping:
            df = df.rename(columns=valid_mapping)
        else:
            print(f"⚠️ Tidak ada kolom yang cocok dengan mapping untuk {filename}. Kolom yang ada: {list(df.columns)}")

    if 'ID' in df.columns:
        df['ID_Numeric'] = df['ID'].apply(extract_numeric_id)
    return df

# MAIN
if __name__ == "__main__":
    print("Direktori kerja saat ini:", os.getcwd())
    print("File di direktori kerja:", os.listdir(os.getcwd()))
    drive_path = '/content/drive/MyDrive/DATASET'
    if os.path.exists(drive_path):
        print("File di /content/drive/MyDrive/DATASET:", os.listdir(drive_path))
    else:
        print("Folder /content/drive/MyDrive/DATASET tidak ditemukan")

    for filename, path in all_datasets.items():
        print(f"\n================== MEMUAT DATASET: {filename} ==================")
        try:
            if not path.startswith('http'):
                if not os.path.exists(path):
                    print(f"❌ File {filename} tidak ditemukan di: {path}")
                    print("Pastikan file ada di folder /content/drive/MyDrive/DATASET/")
                    continue

            if path.endswith('.xlsx'):
                df = pd.read_excel(path)
            else:
                df = pd.read_csv(path)

            df.columns = [col.strip() for col in df.columns]
            print(f"Kolom asli: {list(df.columns)}")
            df = normalize_columns(df, filename)
            expected_columns = ['ID', 'Nama Pelanggan', 'Tanggal Pembelian', 'Jumlah Pembelian', 'ID_Numeric']

            available_columns = [col for col in expected_columns if col in df.columns]
            if len(available_columns) < 4:
                print(f"❌ Dataset {filename} tidak memiliki kolom yang cukup. Kolom yang hilang: {[col for col in expected_columns if col not in df.columns]}")
                print(f"Kolom yang ada: {list(df.columns)}")
                continue
            df = df[available_columns].copy()

            df['ID_Numeric'] = pd.to_numeric(df['ID_Numeric'], errors='coerce').astype('Int64')
            df['Jumlah Pembelian'] = pd.to_numeric(df['Jumlah Pembelian'], errors='coerce')
            if filename == 'data_transaksi.csv':
                df['Tanggal Pembelian'] = pd.to_datetime(df['Tanggal Pembelian'], format='%Y-%m-%d', errors='coerce').dt.strftime('%d/%m/%Y')
            else:
                df['Tanggal Pembelian'] = pd.to_datetime(df['Tanggal Pembelian'], errors='coerce').dt.strftime('%d/%m/%Y')

            missing_rows = df[df[available_columns].isna().any(axis=1)]
            if not missing_rows.empty:
                print(f"⚠️ {len(missing_rows)} baris dengan nilai kosong di kolom kunci: {missing_rows.head().to_dict(orient='records')}")

            df = df.dropna(subset=available_columns)

            transaksi_data = df.to_dict(orient='records')
            print(f"✅ Jumlah Data: {len(transaksi_data)}")
            print("Contoh Data (5 data pertama):")
            for txn in transaksi_data[:5]:
                print(txn)

            if transaksi_data:
                benchmark(transaksi_data, filename)
            else:
                print(f"⚠️ Tidak ada data transaksi yang valid di {filename} setelah pemrosesan. Melewati benchmark.")
        except FileNotFoundError:
            print(f"❌ Gagal memproses dataset {filename}: File tidak ditemukan di lokasi: {path}")
        except Exception as e:
            print(f"❌ Gagal memproses dataset {filename}: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Direktori kerja saat ini: /content
# File di direktori kerja: ['.config', 'drive', 'sample_data']
# File di /content/drive/MyDrive/DATASET: ['Dataset Penjualan Buku.csv', 'dataset_tiruan.xlsx', 'synthetic (1).csv', 'olist_products_dataset.csv', 'olist_orders_dataset.csv']
#
# ================== MEMUAT DATASET: penjualan barang.csv ==================
# Kolom asli: ['Unnamed: 0', 'tanggal', 'nama.pembeli', 'nama.barang', 'kuantum', 'nominal']
# ✅ Jumlah Data: 1289
# Contoh Data (5 data pertama):
# {'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}
# {'ID': 2, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 8400000.0, 'ID_Numeric': 2}
# {'ID': 3, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 62910000.0, 'ID_Numeric': 3}
# {'ID': 4, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 4855200.0, 'ID_Numeric': 4}
# {'ID': 5, 'Nama Pelanggan': 'TOKO APRILIA SUKRISNI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 1162000.0, 'ID_Numeric': 5}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID_Numeric ---
#
# [1] Sequence Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000003 detik
# Ruang Memori: 11288 bytes
#
# [2] Binary Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000005 detik
# Ruang Memori: 10376 bytes
#
# [3] Bubble Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Bubble Sort: 0.000218 detik
# Ruang Memori: 10368 bytes
#
# [4] Selection Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Selection Sort: 0.123265 detik
# Ruang Memori: 10368 bytes
#
# [5] Sequence-Bubble (by ID_Numeric)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Sequence-Bubble: 0.000269 detik
# Ruang Memori: 10368 bytes
#
# [6] Sequence-Selection (by ID_Numeric)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Sequence-Selection: 0.124130 detik
# Ruang Memori: 10368 bytes
#
# [7] Binary-Bubble (by ID_Numeric)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Binary-Bubble: 0.000454 detik
# Ruang Memori: 10368 bytes
#
# [8] Binary-Selection (by ID_Numeric)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Binary-Selection: 0.134993 detik
# Ruang Memori: 10368 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Sequence Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000005 detik
# Ruang Memori: 11288 bytes
#
# [2] Binary Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 101, 'Nama Pelanggan': 'TPK PASAR JUNJUNG BUIH', 'Tanggal Pembelian': '03/02/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 101}]
# Waktu Binary Search: 0.000006 detik
# Ruang Memori: 10376 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [46000.0, 69000.0, 92000.0, 92000.0, 92000.0]
# Waktu Bubble Sort: 0.185287 detik
# Ruang Memori: 10368 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [46000.0, 69000.0, 92000.0, 92000.0, 92000.0]
# Waktu Selection Sort: 0.133326 detik
# Ruang Memori: 10368 bytes
#
# [5] Sequence-Bubble (by Jumlah Pembelian)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [46000.0, 69000.0, 92000.0, 92000.0, 92000.0]
# Waktu Sequence-Bubble: 0.188519 detik
# Ruang Memori: 10368 bytes
#
# [6] Sequence-Selection (by Jumlah Pembelian)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [46000.0, 69000.0, 92000.0, 92000.0, 92000.0]
# Waktu Sequence-Selection: 0.130978 detik
# Ruang Memori: 10368 bytes
#
# [7] Binary-Bubble (by Jumlah Pembelian)...
# Binary Search sebelum Bubble Sort: [{'ID': 101, 'Nama Pelanggan': 'TPK PASAR JUNJUNG BUIH', 'Tanggal Pembelian': '03/02/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 101}]
# Hasil (5 data pertama): [46000.0, 69000.0, 92000.0, 92000.0, 92000.0]
# Waktu Binary-Bubble: 0.187616 detik
# Ruang Memori: 10368 bytes
#
# [8] Binary-Selection (by Jumlah Pembelian)...
# Binary Search sebelum Selection Sort: [{'ID': 101, 'Nama Pelanggan': 'TPK PASAR JUNJUNG BUIH', 'Tanggal Pembelian': '03/02/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 101}]
# Hasil (5 data pertama): [46000.0, 69000.0, 92000.0, 92000.0, 92000.0]
# Waktu Binary-Selection: 0.132740 detik
# Ruang Memori: 10368 bytes
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Sequence Search (by Nama Pelanggan)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000005 detik
# Ruang Memori: 11288 bytes
#
# [2] Binary Search (by Nama Pelanggan)...
# Hasil: [{'ID': 216, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '09/03/2020', 'Jumlah Pembelian': 6868400.0, 'ID_Numeric': 216}]
# Waktu Binary Search: 0.000005 detik
# Ruang Memori: 10376 bytes
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA']
# Waktu Bubble Sort: 0.204172 detik
# Ruang Memori: 10368 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA']
# Waktu Selection Sort: 0.140486 detik
# Ruang Memori: 10368 bytes
#
# [5] Sequence-Bubble (by Nama Pelanggan)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA']
# Waktu Sequence-Bubble: 0.188951 detik
# Ruang Memori: 10368 bytes
#
# [6] Sequence-Selection (by Nama Pelanggan)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA']
# Waktu Sequence-Selection: 0.137355 detik
# Ruang Memori: 10368 bytes
#
# [7] Binary-Bubble (by Nama Pelanggan)...
# Binary Search sebelum Bubble Sort: [{'ID': 216, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '09/03/2020', 'Jumlah Pembelian': 6868400.0, 'ID_Numeric': 216}]
# Hasil (5 data pertama): ['ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA']
# Waktu Binary-Bubble: 0.187584 detik
# Ruang Memori: 10368 bytes
#
# [8] Binary-Selection (by Nama Pelanggan)...
# Binary Search sebelum Selection Sort: [{'ID': 216, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '09/03/2020', 'Jumlah Pembelian': 6868400.0, 'ID_Numeric': 216}]
# Hasil (5 data pertama): ['ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA', 'ANAPSA']
# Waktu Binary-Selection: 0.137961 detik
# Ruang Memori: 10368 bytes
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Sequence Search (by Tanggal Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000003 detik
# Ruang Memori: 11288 bytes
#
# [2] Binary Search (by Tanggal Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000004 detik
# Ruang Memori: 10376 bytes
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021']
# Waktu Bubble Sort: 0.210657 detik
# Ruang Memori: 10368 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021']
# Waktu Selection Sort: 0.140630 detik
# Ruang Memori: 10368 bytes
#
# [5] Sequence-Bubble (by Tanggal Pembelian)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021']
# Waktu Sequence-Bubble: 0.189699 detik
# Ruang Memori: 10368 bytes
#
# [6] Sequence-Selection (by Tanggal Pembelian)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021']
# Waktu Sequence-Selection: 0.137557 detik
# Ruang Memori: 10368 bytes
#
# [7] Binary-Bubble (by Tanggal Pembelian)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021']
# Waktu Binary-Bubble: 0.187895 detik
# Ruang Memori: 10368 bytes
#
# [8] Binary-Selection (by Tanggal Pembelian)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'TOKO HERUNIAWATI', 'Tanggal Pembelian': '02/01/2020', 'Jumlah Pembelian': 9840000.0, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021', '01/02/2021']
# Waktu Binary-Selection: 0.137950 detik
# Ruang Memori: 10368 bytes
#
# ================== MEMUAT DATASET: data_transaksi.csv ==================
# Kolom asli: ['id', 'nama', 'tanggal', 'jumlah']
# ✅ Jumlah Data: 10000
# Contoh Data (5 data pertama):
# {'ID': 0, 'Nama Pelanggan': 'OMODF', 'Tanggal Pembelian': '28/10/2024', 'Jumlah Pembelian': 839.53, 'ID_Numeric': 0}
# {'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}
# {'ID': 2, 'Nama Pelanggan': 'MJHYJ', 'Tanggal Pembelian': '29/07/2024', 'Jumlah Pembelian': 103.66, 'ID_Numeric': 2}
# {'ID': 3, 'Nama Pelanggan': 'XTQTS', 'Tanggal Pembelian': '02/12/2025', 'Jumlah Pembelian': 191.2, 'ID_Numeric': 3}
# {'ID': 4, 'Nama Pelanggan': 'SFLLP', 'Tanggal Pembelian': '26/03/2025', 'Jumlah Pembelian': 143.33, 'ID_Numeric': 4}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID_Numeric ---
#
# [1] Sequence Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000003 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000006 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by ID_Numeric)...
# Hasil (5 data pertama): [0, 1, 2, 3, 4]
# Waktu Bubble Sort: 0.001781 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by ID_Numeric)...
# Hasil (5 data pertama): [0, 1, 2, 3, 4]
# Waktu Selection Sort: 8.951216 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by ID_Numeric)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [0, 1, 2, 3, 4]
# Waktu Sequence-Bubble: 0.003844 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by ID_Numeric)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [0, 1, 2, 3, 4]
# Waktu Sequence-Selection: 7.425784 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by ID_Numeric)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [0, 1, 2, 3, 4]
# Waktu Binary-Bubble: 0.004094 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by ID_Numeric)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [0, 1, 2, 3, 4]
# Waktu Binary-Selection: 9.070810 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Sequence Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000006 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000008 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [10.04, 10.08, 10.14, 10.22, 10.31]
# Waktu Bubble Sort: 14.704287 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [10.04, 10.08, 10.14, 10.22, 10.31]
# Waktu Selection Sort: 10.834816 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Jumlah Pembelian)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [10.04, 10.08, 10.14, 10.22, 10.31]
# Waktu Sequence-Bubble: 14.588177 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Jumlah Pembelian)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [10.04, 10.08, 10.14, 10.22, 10.31]
# Waktu Sequence-Selection: 11.266394 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Jumlah Pembelian)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [10.04, 10.08, 10.14, 10.22, 10.31]
# Waktu Binary-Bubble: 14.694668 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by Jumlah Pembelian)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [10.04, 10.08, 10.14, 10.22, 10.31]
# Waktu Binary-Selection: 11.032289 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Sequence Search (by Nama Pelanggan)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000006 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Nama Pelanggan)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000008 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['AACCL', 'AACFT', 'AAFDL', 'AAFNP', 'AAMIK']
# Waktu Bubble Sort: 14.603684 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['AACCL', 'AACFT', 'AAFDL', 'AAFNP', 'AAMIK']
# Waktu Selection Sort: 10.972592 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Nama Pelanggan)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['AACCL', 'AACFT', 'AAFDL', 'AAFNP', 'AAMIK']
# Waktu Sequence-Bubble: 14.768919 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Nama Pelanggan)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['AACCL', 'AACFT', 'AAFDL', 'AAFNP', 'AAMIK']
# Waktu Sequence-Selection: 11.095413 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Nama Pelanggan)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['AACCL', 'AACFT', 'AAFDL', 'AAFNP', 'AAMIK']
# Waktu Binary-Bubble: 14.772485 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by Nama Pelanggan)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['AACCL', 'AACFT', 'AAFDL', 'AAFNP', 'AAMIK']
# Waktu Binary-Selection: 11.025361 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Sequence Search (by Tanggal Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000005 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Tanggal Pembelian)...
# Hasil: [{'ID': 3767, 'Nama Pelanggan': 'WIMUQ', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 861.59, 'ID_Numeric': 3767}]
# Waktu Binary Search: 0.000008 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023']
# Waktu Bubble Sort: 15.294260 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023']
# Waktu Selection Sort: 11.429056 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Tanggal Pembelian)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023']
# Waktu Sequence-Bubble: 15.332439 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Tanggal Pembelian)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'QDFKU', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 809.47, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023']
# Waktu Sequence-Selection: 11.403902 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Tanggal Pembelian)...
# Binary Search sebelum Bubble Sort: [{'ID': 3767, 'Nama Pelanggan': 'WIMUQ', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 861.59, 'ID_Numeric': 3767}]
# Hasil (5 data pertama): ['01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023']
# Waktu Binary-Bubble: 15.335210 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by Tanggal Pembelian)...
# Binary Search sebelum Selection Sort: [{'ID': 3767, 'Nama Pelanggan': 'WIMUQ', 'Tanggal Pembelian': '04/07/2023', 'Jumlah Pembelian': 861.59, 'ID_Numeric': 3767}]
# Hasil (5 data pertama): ['01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023', '01/01/2023']
# Waktu Binary-Selection: 11.392383 detik
# Ruang Memori: 80056 bytes
#
# ================== MEMUAT DATASET: synthetic (1).csv ==================
# Kolom asli: ['ID Pelanggan', 'Nama Pelanggan', 'Waktu Pembelian', 'Jumlah Pembelian']
# ✅ Jumlah Data: 10000
# Contoh Data (5 data pertama):
# {'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}
# {'ID': 2, 'Nama Pelanggan': 'Kirana Susanti', 'Tanggal Pembelian': '28/09/2024', 'Jumlah Pembelian': 21199, 'ID_Numeric': 2}
# {'ID': 3, 'Nama Pelanggan': 'Gita Bayhaqie', 'Tanggal Pembelian': '19/07/2024', 'Jumlah Pembelian': 39819, 'ID_Numeric': 3}
# {'ID': 4, 'Nama Pelanggan': 'Aditya Wulandari', 'Tanggal Pembelian': '14/03/2024', 'Jumlah Pembelian': 485896, 'ID_Numeric': 4}
# {'ID': 5, 'Nama Pelanggan': 'Omar Sulistyo', 'Tanggal Pembelian': '22/07/2024', 'Jumlah Pembelian': 72706, 'ID_Numeric': 5}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID_Numeric ---
#
# [1] Sequence Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000003 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000006 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Bubble Sort: 0.001921 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Selection Sort: 7.758481 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by ID_Numeric)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Sequence-Bubble: 0.003740 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by ID_Numeric)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Sequence-Selection: 8.566063 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by ID_Numeric)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Binary-Bubble: 0.003458 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by ID_Numeric)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Binary-Selection: 8.907280 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Sequence Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000005 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000007 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [10001, 10022, 10131, 10164, 10247]
# Waktu Bubble Sort: 14.743168 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [10001, 10022, 10131, 10164, 10247]
# Waktu Selection Sort: 10.950524 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Jumlah Pembelian)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [10001, 10022, 10131, 10164, 10247]
# Waktu Sequence-Bubble: 14.728568 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Jumlah Pembelian)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [10001, 10022, 10131, 10164, 10247]
# Waktu Sequence-Selection: 10.924812 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Jumlah Pembelian)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [10001, 10022, 10131, 10164, 10247]
# Waktu Binary-Bubble: 14.751440 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by Jumlah Pembelian)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [10001, 10022, 10131, 10164, 10247]
# Waktu Binary-Selection: 10.960030 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Sequence Search (by Nama Pelanggan)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000006 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Nama Pelanggan)...
# Hasil: [{'ID': 6071, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/12/2024', 'Jumlah Pembelian': 389059, 'ID_Numeric': 6071}]
# Waktu Binary Search: 0.000008 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['Abdi Adinata', 'Abdi Aji', 'Abdi Almira', 'Abdi Almira', 'Abdi Almira']
# Waktu Bubble Sort: 14.688259 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['Abdi Adinata', 'Abdi Aji', 'Abdi Almira', 'Abdi Almira', 'Abdi Almira']
# Waktu Selection Sort: 11.324633 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Nama Pelanggan)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['Abdi Adinata', 'Abdi Aji', 'Abdi Almira', 'Abdi Almira', 'Abdi Almira']
# Waktu Sequence-Bubble: 14.797284 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Nama Pelanggan)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['Abdi Adinata', 'Abdi Aji', 'Abdi Almira', 'Abdi Almira', 'Abdi Almira']
# Waktu Sequence-Selection: 11.252683 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Nama Pelanggan)...
# Binary Search sebelum Bubble Sort: [{'ID': 6071, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/12/2024', 'Jumlah Pembelian': 389059, 'ID_Numeric': 6071}]
# Hasil (5 data pertama): ['Abdi Adinata', 'Abdi Aji', 'Abdi Almira', 'Abdi Almira', 'Abdi Almira']
# Waktu Binary-Bubble: 14.834495 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by Nama Pelanggan)...
# Binary Search sebelum Selection Sort: [{'ID': 6071, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/12/2024', 'Jumlah Pembelian': 389059, 'ID_Numeric': 6071}]
# Hasil (5 data pertama): ['Abdi Adinata', 'Abdi Aji', 'Abdi Almira', 'Abdi Almira', 'Abdi Almira']
# Waktu Binary-Selection: 10.843215 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Sequence Search (by Tanggal Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000004 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Tanggal Pembelian)...
# Hasil: [{'ID': 7105, 'Nama Pelanggan': 'Yohan Supriyadi', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 348118, 'ID_Numeric': 7105}]
# Waktu Binary Search: 0.000008 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024']
# Waktu Bubble Sort: 15.808733 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024']
# Waktu Selection Sort: 11.244495 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Tanggal Pembelian)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024']
# Waktu Sequence-Bubble: 15.115226 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Tanggal Pembelian)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Udin Sari', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 275031, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024']
# Waktu Sequence-Selection: 11.220817 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Tanggal Pembelian)...
# Binary Search sebelum Bubble Sort: [{'ID': 7105, 'Nama Pelanggan': 'Yohan Supriyadi', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 348118, 'ID_Numeric': 7105}]
# Hasil (5 data pertama): ['01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024']
# Waktu Binary-Bubble: 15.097742 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by Tanggal Pembelian)...
# Binary Search sebelum Selection Sort: [{'ID': 7105, 'Nama Pelanggan': 'Yohan Supriyadi', 'Tanggal Pembelian': '29/06/2024', 'Jumlah Pembelian': 348118, 'ID_Numeric': 7105}]
# Hasil (5 data pertama): ['01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024', '01/01/2024']
# Waktu Binary-Selection: 11.217267 detik
# Ruang Memori: 80056 bytes
#
# ================== MEMUAT DATASET: Dataset Penjualan Buku.csv ==================
# Kolom asli: ['ID', 'Nama_Pelanggan', 'Tanggal_Pembelian', 'Jumlah_Pembelian', 'Kategori_Buku', 'Harga_Satuan', 'Total_Harga']
# ✅ Jumlah Data: 10000
# Contoh Data (5 data pertama):
# {'ID': 1944, 'Nama Pelanggan': 'Balidin Dongoran, S.T.', 'Tanggal Pembelian': '30/08/2024', 'Jumlah Pembelian': 7, 'ID_Numeric': 1944}
# {'ID': 2455, 'Nama Pelanggan': 'Darmana Mandala', 'Tanggal Pembelian': '05/12/2024', 'Jumlah Pembelian': 20, 'ID_Numeric': 2455}
# {'ID': 3512, 'Nama Pelanggan': 'Ciaobella Wastuti, M.Pd', 'Tanggal Pembelian': '14/08/2024', 'Jumlah Pembelian': 15, 'ID_Numeric': 3512}
# {'ID': 3354, 'Nama Pelanggan': 'Lantar Anggraini', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 11, 'ID_Numeric': 3354}
# {'ID': 2721, 'Nama Pelanggan': 'Among Iswahyudi', 'Tanggal Pembelian': '04/07/2024', 'Jumlah Pembelian': 8, 'ID_Numeric': 2721}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID_Numeric ---
#
# [1] Sequence Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000462 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000008 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Bubble Sort: 13.717643 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Selection Sort: 8.631248 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by ID_Numeric)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Sequence-Bubble: 14.233019 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by ID_Numeric)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Sequence-Selection: 9.648732 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by ID_Numeric)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Binary-Bubble: 13.652138 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by ID_Numeric)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 2, 3, 4, 5]
# Waktu Binary-Selection: 10.082062 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Sequence Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 1510, 'Nama Pelanggan': 'Tgk. Yani Gunawan', 'Tanggal Pembelian': '10/12/2024', 'Jumlah Pembelian': 6, 'ID_Numeric': 1510}]
# Waktu Sequence Search: 0.000012 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 9648, 'Nama Pelanggan': 'Putu Sihombing, S.Sos', 'Tanggal Pembelian': '19/01/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 9648}]
# Waktu Binary Search: 0.000005 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Bubble Sort: 13.716435 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Selection Sort: 10.156249 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Jumlah Pembelian)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1510, 'Nama Pelanggan': 'Tgk. Yani Gunawan', 'Tanggal Pembelian': '10/12/2024', 'Jumlah Pembelian': 6, 'ID_Numeric': 1510}]
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Sequence-Bubble: 13.684921 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Jumlah Pembelian)...
# Sequence Search sebelum Selection Sort: [{'ID': 1510, 'Nama Pelanggan': 'Tgk. Yani Gunawan', 'Tanggal Pembelian': '10/12/2024', 'Jumlah Pembelian': 6, 'ID_Numeric': 1510}]
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Sequence-Selection: 10.240968 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Jumlah Pembelian)...
# Binary Search sebelum Bubble Sort: [{'ID': 9648, 'Nama Pelanggan': 'Putu Sihombing, S.Sos', 'Tanggal Pembelian': '19/01/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 9648}]
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Binary-Bubble: 13.743532 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by Jumlah Pembelian)...
# Binary Search sebelum Selection Sort: [{'ID': 9648, 'Nama Pelanggan': 'Putu Sihombing, S.Sos', 'Tanggal Pembelian': '19/01/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 9648}]
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Binary-Selection: 8.668212 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Sequence Search (by Nama Pelanggan)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000428 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Nama Pelanggan)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000008 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['Abyasa Firgantoro, S.Sos', 'Abyasa Habibi', 'Abyasa Lazuardi', 'Abyasa Prasetyo', 'Abyasa Purwanti']
# Waktu Bubble Sort: 16.123527 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['Abyasa Firgantoro, S.Sos', 'Abyasa Habibi', 'Abyasa Lazuardi', 'Abyasa Prasetyo', 'Abyasa Purwanti']
# Waktu Selection Sort: 10.241097 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Nama Pelanggan)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['Abyasa Firgantoro, S.Sos', 'Abyasa Habibi', 'Abyasa Lazuardi', 'Abyasa Prasetyo', 'Abyasa Purwanti']
# Waktu Sequence-Bubble: 16.326953 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Nama Pelanggan)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['Abyasa Firgantoro, S.Sos', 'Abyasa Habibi', 'Abyasa Lazuardi', 'Abyasa Prasetyo', 'Abyasa Purwanti']
# Waktu Sequence-Selection: 10.093211 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Nama Pelanggan)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['Abyasa Firgantoro, S.Sos', 'Abyasa Habibi', 'Abyasa Lazuardi', 'Abyasa Prasetyo', 'Abyasa Purwanti']
# Waktu Binary-Bubble: 16.716976 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by Nama Pelanggan)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Tira Palastri, S.Kom', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 6, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['Abyasa Firgantoro, S.Sos', 'Abyasa Habibi', 'Abyasa Lazuardi', 'Abyasa Prasetyo', 'Abyasa Purwanti']
# Waktu Binary-Selection: 9.868222 detik
# Ruang Memori: 80056 bytes
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Sequence Search (by Tanggal Pembelian)...
# Hasil: [{'ID': 3354, 'Nama Pelanggan': 'Lantar Anggraini', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 11, 'ID_Numeric': 3354}]
# Waktu Sequence Search: 0.000006 detik
# Ruang Memori: 85176 bytes
#
# [2] Binary Search (by Tanggal Pembelian)...
# Hasil: [{'ID': 7272, 'Nama Pelanggan': 'Rachel Maryati', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 7, 'ID_Numeric': 7272}]
# Waktu Binary Search: 0.000007 detik
# Ruang Memori: 80056 bytes
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025']
# Waktu Bubble Sort: 16.823990 detik
# Ruang Memori: 80056 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025']
# Waktu Selection Sort: 10.719582 detik
# Ruang Memori: 80056 bytes
#
# [5] Sequence-Bubble (by Tanggal Pembelian)...
# Sequence Search sebelum Bubble Sort: [{'ID': 3354, 'Nama Pelanggan': 'Lantar Anggraini', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 11, 'ID_Numeric': 3354}]
# Hasil (5 data pertama): ['01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025']
# Waktu Sequence-Bubble: 16.155436 detik
# Ruang Memori: 80056 bytes
#
# [6] Sequence-Selection (by Tanggal Pembelian)...
# Sequence Search sebelum Selection Sort: [{'ID': 3354, 'Nama Pelanggan': 'Lantar Anggraini', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 11, 'ID_Numeric': 3354}]
# Hasil (5 data pertama): ['01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025']
# Waktu Sequence-Selection: 11.246376 detik
# Ruang Memori: 80056 bytes
#
# [7] Binary-Bubble (by Tanggal Pembelian)...
# Binary Search sebelum Bubble Sort: [{'ID': 7272, 'Nama Pelanggan': 'Rachel Maryati', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 7, 'ID_Numeric': 7272}]
# Hasil (5 data pertama): ['01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025']
# Waktu Binary-Bubble: 15.687296 detik
# Ruang Memori: 80056 bytes
#
# [8] Binary-Selection (by Tanggal Pembelian)...
# Binary Search sebelum Selection Sort: [{'ID': 7272, 'Nama Pelanggan': 'Rachel Maryati', 'Tanggal Pembelian': '14/04/2025', 'Jumlah Pembelian': 7, 'ID_Numeric': 7272}]
# Hasil (5 data pertama): ['01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025', '01/01/2025']
# Waktu Binary-Selection: 11.495665 detik
# Ruang Memori: 80056 bytes
#
# ================== MEMUAT DATASET: dataset_tiruan.xlsx ==================
# Kolom asli: ['ID', 'Nama Pelanggan', 'Tanggal Pembelian', 'Jumlah Pembelian']
# ⚠️ 6073 baris dengan nilai kosong di kolom kunci: [{'ID': 2, 'Nama Pelanggan': 'Gregory Rodriguez', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 892, 'ID_Numeric': 2}, {'ID': 4, 'Nama Pelanggan': 'Jordan Williams', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 725, 'ID_Numeric': 4}, {'ID': 7, 'Nama Pelanggan': 'Susan Sampson', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 358, 'ID_Numeric': 7}, {'ID': 8, 'Nama Pelanggan': 'Jessica Williams', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 49, 'ID_Numeric': 8}, {'ID': 9, 'Nama Pelanggan': 'Colleen Johnson', 'Tanggal Pembelian': nan, 'Jumlah Pembelian': 784, 'ID_Numeric': 9}]
# ✅ Jumlah Data: 3927
# Contoh Data (5 data pertama):
# {'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}
# {'ID': 3, 'Nama Pelanggan': 'Jessica Allen', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 983, 'ID_Numeric': 3}
# {'ID': 5, 'Nama Pelanggan': 'Jordan Brown', 'Tanggal Pembelian': '02/01/2022', 'Jumlah Pembelian': 847, 'ID_Numeric': 5}
# {'ID': 6, 'Nama Pelanggan': 'Jordan Sampson', 'Tanggal Pembelian': '12/03/2022', 'Jumlah Pembelian': 715, 'ID_Numeric': 6}
# {'ID': 10, 'Nama Pelanggan': 'Susan Sampson', 'Tanggal Pembelian': '02/10/2022', 'Jumlah Pembelian': 377, 'ID_Numeric': 10}
#
# ==================== PENGUJIAN ALGORITMA PENCARIAN DAN PENGURUTAN ====================
#
# --- Benchmarking untuk Kolom: ID_Numeric ---
#
# [1] Sequence Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000003 detik
# Ruang Memori: 33048 bytes
#
# [2] Binary Search (by ID_Numeric)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Waktu Binary Search: 0.000005 detik
# Ruang Memori: 31480 bytes
#
# [3] Bubble Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 3, 5, 6, 10]
# Waktu Bubble Sort: 0.000710 detik
# Ruang Memori: 31472 bytes
#
# [4] Selection Sort (by ID_Numeric)...
# Hasil (5 data pertama): [1, 3, 5, 6, 10]
# Waktu Selection Sort: 1.172869 detik
# Ruang Memori: 31472 bytes
#
# [5] Sequence-Bubble (by ID_Numeric)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 3, 5, 6, 10]
# Waktu Sequence-Bubble: 0.000810 detik
# Ruang Memori: 31472 bytes
#
# [6] Sequence-Selection (by ID_Numeric)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 3, 5, 6, 10]
# Waktu Sequence-Selection: 1.148341 detik
# Ruang Memori: 31472 bytes
#
# [7] Binary-Bubble (by ID_Numeric)...
# Binary Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 3, 5, 6, 10]
# Waktu Binary-Bubble: 0.001475 detik
# Ruang Memori: 31472 bytes
#
# [8] Binary-Selection (by ID_Numeric)...
# Binary Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 3, 5, 6, 10]
# Waktu Binary-Selection: 1.150458 detik
# Ruang Memori: 31472 bytes
#
# --- Benchmarking untuk Kolom: Jumlah Pembelian ---
#
# [1] Sequence Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000005 detik
# Ruang Memori: 33048 bytes
#
# [2] Binary Search (by Jumlah Pembelian)...
# Hasil: [{'ID': 4835, 'Nama Pelanggan': 'Sarah Johnson', 'Tanggal Pembelian': '11/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 4835}]
# Waktu Binary Search: 0.000007 detik
# Ruang Memori: 31480 bytes
#
# [3] Bubble Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Bubble Sort: 1.845755 detik
# Ruang Memori: 31472 bytes
#
# [4] Selection Sort (by Jumlah Pembelian)...
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Selection Sort: 1.322517 detik
# Ruang Memori: 31472 bytes
#
# [5] Sequence-Bubble (by Jumlah Pembelian)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Sequence-Bubble: 1.867784 detik
# Ruang Memori: 31472 bytes
#
# [6] Sequence-Selection (by Jumlah Pembelian)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Sequence-Selection: 2.081747 detik
# Ruang Memori: 31472 bytes
#
# [7] Binary-Bubble (by Jumlah Pembelian)...
# Binary Search sebelum Bubble Sort: [{'ID': 4835, 'Nama Pelanggan': 'Sarah Johnson', 'Tanggal Pembelian': '11/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 4835}]
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Binary-Bubble: 2.650518 detik
# Ruang Memori: 31472 bytes
#
# [8] Binary-Selection (by Jumlah Pembelian)...
# Binary Search sebelum Selection Sort: [{'ID': 4835, 'Nama Pelanggan': 'Sarah Johnson', 'Tanggal Pembelian': '11/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 4835}]
# Hasil (5 data pertama): [1, 1, 1, 1, 1]
# Waktu Binary-Selection: 1.342883 detik
# Ruang Memori: 31472 bytes
#
# --- Benchmarking untuk Kolom: Nama Pelanggan ---
#
# [1] Sequence Search (by Nama Pelanggan)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000004 detik
# Ruang Memori: 33048 bytes
#
# [2] Binary Search (by Nama Pelanggan)...
# Hasil: [{'ID': 7936, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '02/05/2022', 'Jumlah Pembelian': 842, 'ID_Numeric': 7936}]
# Waktu Binary Search: 0.000010 detik
# Ruang Memori: 31480 bytes
#
# [3] Bubble Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen']
# Waktu Bubble Sort: 1.820969 detik
# Ruang Memori: 31472 bytes
#
# [4] Selection Sort (by Nama Pelanggan)...
# Hasil (5 data pertama): ['Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen']
# Waktu Selection Sort: 1.325108 detik
# Ruang Memori: 31472 bytes
#
# [5] Sequence-Bubble (by Nama Pelanggan)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen']
# Waktu Sequence-Bubble: 1.824529 detik
# Ruang Memori: 31472 bytes
#
# [6] Sequence-Selection (by Nama Pelanggan)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen']
# Waktu Sequence-Selection: 1.329483 detik
# Ruang Memori: 31472 bytes
#
# [7] Binary-Bubble (by Nama Pelanggan)...
# Binary Search sebelum Bubble Sort: [{'ID': 7936, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '02/05/2022', 'Jumlah Pembelian': 842, 'ID_Numeric': 7936}]
# Hasil (5 data pertama): ['Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen']
# Waktu Binary-Bubble: 2.252200 detik
# Ruang Memori: 31472 bytes
#
# [8] Binary-Selection (by Nama Pelanggan)...
# Binary Search sebelum Selection Sort: [{'ID': 7936, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '02/05/2022', 'Jumlah Pembelian': 842, 'ID_Numeric': 7936}]
# Hasil (5 data pertama): ['Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen', 'Andrea Allen']
# Waktu Binary-Selection: 2.470929 detik
# Ruang Memori: 31472 bytes
#
# --- Benchmarking untuk Kolom: Tanggal Pembelian ---
#
# [1] Sequence Search (by Tanggal Pembelian)...
# Hasil: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Waktu Sequence Search: 0.000006 detik
# Ruang Memori: 33048 bytes
#
# [2] Binary Search (by Tanggal Pembelian)...
# Hasil: [{'ID': 5757, 'Nama Pelanggan': 'Colleen Williams', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 717, 'ID_Numeric': 5757}]
# Waktu Binary Search: 0.000006 detik
# Ruang Memori: 31480 bytes
#
# [3] Bubble Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022']
# Waktu Bubble Sort: 1.950889 detik
# Ruang Memori: 31472 bytes
#
# [4] Selection Sort (by Tanggal Pembelian)...
# Hasil (5 data pertama): ['01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022']
# Waktu Selection Sort: 1.413613 detik
# Ruang Memori: 31472 bytes
#
# [5] Sequence-Bubble (by Tanggal Pembelian)...
# Sequence Search sebelum Bubble Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022']
# Waktu Sequence-Bubble: 1.970027 detik
# Ruang Memori: 31472 bytes
#
# [6] Sequence-Selection (by Tanggal Pembelian)...
# Sequence Search sebelum Selection Sort: [{'ID': 1, 'Nama Pelanggan': 'Michael Bishop', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 880, 'ID_Numeric': 1}]
# Hasil (5 data pertama): ['01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022']
# Waktu Sequence-Selection: 1.392699 detik
# Ruang Memori: 31472 bytes
#
# [7] Binary-Bubble (by Tanggal Pembelian)...
# Binary Search sebelum Bubble Sort: [{'ID': 5757, 'Nama Pelanggan': 'Colleen Williams', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 717, 'ID_Numeric': 5757}]
# Hasil (5 data pertama): ['01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022']
# Waktu Binary-Bubble: 1.955474 detik
# Ruang Memori: 31472 bytes
#
# [8] Binary-Selection (by Tanggal Pembelian)...
# Binary Search sebelum Selection Sort: [{'ID': 5757, 'Nama Pelanggan': 'Colleen Williams', 'Tanggal Pembelian': '08/09/2022', 'Jumlah Pembelian': 717, 'ID_Numeric': 5757}]
# Hasil (5 data pertama): ['01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022', '01/01/2022']
# Waktu Binary-Selection: 1.679011 detik
# Ruang Memori: 31472 bytes

# %%
'olist_orders_dataset.csv': '/content/drive/MyDrive/DATASET/olist_orders_dataset.csv',
'olist_products_dataset.csv': '/content/drive/MyDrive/DATASET/olist_products_dataset.csv'
